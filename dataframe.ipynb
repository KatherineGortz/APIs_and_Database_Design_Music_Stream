# %%
import requests
import pandas as pd
import mysql.connector
# !pip install pandas mysql-connector-python
# Out:
# Requirement already satisfied: pandas in c:\users\usuario\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: mysql-connector-python in c:\users\usuario\anaconda3\lib\site-packages (9.1.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
df = pd.read_csv('./CSV/resultados_artistas.csv')

# %%
df.fillna('Sin datos', inplace=True)

# %%
resultados_artistas = df.values.tolist()

# %%
resultados_artistas
# Out:
# [['0',
#   37100,
#   7870,
#   '1. 0 is a black metal band from Iceland, consisting of:\n\nD.G. - Guitars\nTMS - Drums\nS.S. - Vocals\nÖ.S. - Guitars\nH.K.F. - Bass \n\nThey have released two full length albums to date; 2014\'s Null & Void, and 2020\'s Entity. <a href="https://www.last.fm/music/+noredirect/0">Read more on Last.fm</a>',
#   'Sin datos'],
#  ['DJ Snake',
#   35832115,
#   1988314,
#   'William Grigahcine, better known by his stage name DJ Snake, is a franco-algerian DJ, rapper and producer mixing hip hop and electronic music.\n\nHe is a Grammy-nominated producer and artist who debuted into the international scene with singles "Bird Machine" and "Turn Down for What" in 2013. "Bird Machine" is a collaboration with fellow French act Alesia. The single was picked up by Mad Decent, a Los Angeles-based record label run by Diplo, and released in February 2013. <a href="https://www.last.fm/music/DJ+Snake">Read more on Last.fm</a>',
#   'Martin Garrix, Jack Ü, David Guetta, Jonas Blue, Marshmello'],
#  ['Maribou State',
#   10792893,
#   520789,
#   'Maribou State is Chris Davids and Liam Ivory from Hertfordshire. Liam asked Chris to play bass for his band. When they moved up north to go to university, the band fell by the wayside and the pair began making electronic music in their home studio, forging a partnership that would soon become Maribou State.\n\nIn the summer of 2011 they were scouted by Fat! Records and put out their debut release, the \'Olivia\' EP, which set a blueprint for Maribou State\'s trademark bass-heavy, melodic sound. <a href="https://www.last.fm/music/Maribou+State">Read more on Last.fm</a>',
#   'Catching Flies, George Fitzgerald, Tourist, Elder Island, Bonobo'],
#  ['Xinobi',
#   1041975,
#   161177,
#   'Xinobi is a part of a generation that grew up within the music-blog eruption fueled by Do It Yourself ethics. His sophomore album On The Quiet was up-fronted by the hits Far Away Place and Searching For (a collaboration with Lazarusman). A dance floor-focused story about the transition of many electronic musicians from punk rock & skateboarding into house music and about how dance-music can be a field for social conscious awareness. In the following years <a href="https://www.last.fm/music/Xinobi">Read more on Last.fm</a>',
#   'Moullinex, Gallago, Agoria, Klangkarussell, Eli & Fur'],
#  ['Rhye',
#   16512246,
#   723439,
#   'Rhye is the musical project of Toronto native Milosh. Originally conceived as a collaboration between him and Robin Hannibal of Danish electro-soul outfit Quadron, the project has evolved into a music collective led by Milosh and focused around its associated live band.   <a href="https://www.last.fm/music/Rhye">Read more on Last.fm</a>',
#   'Her, Neil Frances, Two Another, Jamie Woon, Låpsley'],
#  ['Ash',
#   13133185,
#   824059,
#   'There are 4 artists with this name.\n\n1) Ash is an alternative rock band that formed in Downpatrick, Northern Ireland in 1992. The media originally pegged Ash\'s music as Britpop when the band first found mainstream success.\n\nThe current line-up of the group is as follows: Tim Wheeler (vocals and guitar), Mark Hamilton (bass guitar) and Rick McMurray (drums).\n\nAsh\'s full-length debut "1977" was released in 1996 and followed 1994\'s mini album "Trailer". <a href="https://www.last.fm/music/Ash">Read more on Last.fm</a>',
#   'Feeder, Shed Seven, The Bluetones, Dodgy, Idlewild'],
#  ['Guy Gerber',
#   1046585,
#   152263,
#   'The man responsible for those ends of night moments on some of the most respected dance floors across the globe is more than likely Guy Gerber.\n\nAs cited in the UK dance floor bible Mixmag, his universally embraced single on Bedrock Records "Stoppage Time" became a stand out anthem at the likes of Cocoon at Amnesia, and Dc10 in Ibiza along with Secretsundaze in London. The single has surpassed the 5-digit mark in sales and continues to shift by the truckload and to appear on numerous compilations from artists as diverse as BPitch Controls Kiki <a href="https://www.last.fm/music/Guy+Gerber">Read more on Last.fm</a>',
#   'Guy J, Fideles, Minilogue, Mathew Jonson, Sven Väth'],
#  ['Fatboy Slim',
#   41288467,
#   2335976,
#   'Fatboy Slim is a pseudonym of Quentin Leo Cook (b. 31 Jul 1963 in Reigate, Surrey - aka Norman Cook), an English big beat musician.\n\nQuentin Leo Cook was educated at Reigate Grammar School. He started a punk fanzine titled Peroxide with his neighbour Andrew Thomas and art student Ian McKay (formerly Laidlaw). Contemporary with his publishing activities, he played drums in Disque Attack (a British new-wave-influenced rock band) for which he later performed lead vocals. <a href="https://www.last.fm/music/Fatboy+Slim">Read more on Last.fm</a>',
#   'The Chemical Brothers, The Prodigy, Apollo 440, Propellerheads, Groove Armada'],
#  ['Thom Yorke',
#   44320540,
#   1505059,
#   'Thomas Edward Yorke is an English musician who is the main vocalist and songwriter of the rock band Radiohead. A multi-instrumentalist, he mainly plays guitar and keyboards and is noted for his falsetto. He has been described by Rolling Stone as one of the greatest and most influential singers of his generation.\n\nYorke formed Radiohead with schoolmates at Abingdon School in Oxfordshire. Their 1992 debut single, "Creep", made Yorke a celebrity, and Radiohead went on to achieve critical acclaim and sales of over 30 million albums. <a href="https://www.last.fm/music/Thom+Yorke">Read more on Last.fm</a>',
#   'Atoms for Peace, Radiohead, Burial & Four Tet & Thom Yorke, Jonny Greenwood, Philip Selway'],
#  ['El Búho',
#   770948,
#   61338,
#   'El Buho aka Robin Perkins is an English musician living in Amsterdam.  \n\nHe is bridging the gap between Latin American rhythms, digital bleeps, owl bass and found sounds, inspired by Birds, Cumbia, the Andes, Bass, clicks & claps.\n\nHis radio show Rhythm and Roots on Groovalizacion radio is a fantastic introduction to sounds from all over the world and throws the Subtropikal nights in Amsterdam, lived a year in Buenos Aires, where unbeknownst to both, were both in the crowd of the famed ZZK parties, finding inspiration for what was to come. <a href="https://www.last.fm/music/El+B%C3%BAho">Read more on Last.fm</a>',
#   'Chancha Vía Circuito, Chancha Via Circuito, Umoja, Joaquín Cornejo, Yaima'],
#  ['Gaullin',
#   2683293,
#   231765,
#   ' <a href="https://www.last.fm/music/Gaullin">Read more on Last.fm</a>',
#   'Dwin, Dynoro, Chico Rose, Vize, LIUFO'],
#  ['BICEP',
#   11183385,
#   506685,
#   'Belfast-born/London-based duo Bicep (Matt McBriar & Andy Ferguson) are childhood friends who bonded over a shared love of dance music. In the decades since first meeting, aged 8, Bicep have become one of the world’s most avidly appreciated curators & producers of electronic music.\n\nRecently hailed by the BBC as “one of the biggest names in UK dance”, Bicep continue to cement themselves as one of the defining global electronic acts of our times. <a href="https://www.last.fm/music/Bicep">Read more on Last.fm</a>',
#   'Overmono, Ross From Friends, DJ Seinfeld, Mall Grab, George Fitzgerald'],
#  ['Jean-Michel Jarre',
#   2831200,
#   157667,
#   'Jean Michel André Jarre (born in 24 August 1948, Lyon) is a French composer, performer and music producer, regarded as a pioneer of electronic music. He is well-known for huge outdoor shows which feature lights, projections, lasers and fireworks.\n\nJarre hold four Guiness World Records for biggest concert audience: Place De La Concorde (1979, 1 mil.), Rendez-Vous Houston (1986, 1.5 mil.), Paris La Defense (1990 2 mil.) and Oxygen in Moscow (1997, 3. <a href="https://www.last.fm/music/+noredirect/Jean-Michel+Jarre">Read more on Last.fm</a>',
#   'Sin datos'],
#  ['Adam Beyer',
#   1337877,
#   174626,
#   'Adam Beyer\'s music is synonymous with all that is exciting about techno. Having emerged as the figurehead of the hugely prolific Swedish techno scene, Beyer\'s focused and considered approach to his craft has worked to confirm his position as a globally recognized DJ and producer who headlines the worlds cutting edge clubs and festivals week-in-week-out. However life in music began for Beyer down in the grassroots; making the most of Stockholm\'s blossoming techno scene and working in the city\'s renowned Planet Rhythm record store. <a href="https://www.last.fm/music/Adam+Beyer">Read more on Last.fm</a>',
#   'Bart Skils, Layton Giordani, Wehbba, Pig & Dan, Lilly Palmer'],
#  ['Nicolas Godin',
#   836713,
#   118050,
#   'Nicolas Godin (born 25 December 1969 in Le Chesnay near Paris, (Île-de-France / France) is a musician best known for his work with the band Air.\n\nHe plays bass guitar, acoustic guitar and electric guitar, and also provides vocals, including Vocoder vocals. <a href="https://www.last.fm/music/Nicolas+Godin">Read more on Last.fm</a>',
#   'JB Dunckel, Air, Sébastien Tellier, Bent, Zero 7'],
#  ['Califato ¾',
#   494744,
#   19128,
#   ' <a href="https://www.last.fm/music/Califato+%C2%BE">Read more on Last.fm</a>',
#   "La Plazuela, VVV [Trippin'you], Enrique Morente, Lole Y Manuel, Soleá Morente"],
#  ['Rebūke',
#   398301,
#   66138,
#   'If you want to arrive with a bang, you can’t do much better than Rebūke. A project forged in the white-hot atmospheres of the Irish underground music scene has ushered in the biggest breakout star of the last 18 months – and one of the most exciting new artists in years.\n\nRebūke is a DJ and producer creating something new and genuinely exciting. A soundclash of techno, house and rave records from the early ‘90s creates that elusive thing – a sound of his own. <a href="https://www.last.fm/music/Reb%C5%ABke">Read more on Last.fm</a>',
#   'Mossano, 8Kays, Kevin De Vries, Argy, Layton Giordani'],
#  ['Novalima',
#   438405,
#   60149,
#   'Novalima is a production collective created in 2001 by four Peruvian musicians (Ramon Perez Prieto, Carlos Li Carrillo, Grimaldo del Solar and Rafael Morales) based in Barcelona, Hong Kong, London, and Lima. Its music is heavily driven by afro-peruvian and latin percussions, blended with downtempo, dub, broken and house beats. In 2003, the collective produced its debut album – novalima -, mixed at The Premises Studios in London, mastered in Sterling Sound, NY, and independently released in March of that year.  <a href="https://www.last.fm/music/Novalima">Read more on Last.fm</a>',
#   'Thornato, Los Destellos, Chicha Libre, La Yegros, Bomba Estéreo'],
#  ['LOUTA',
#   1827478,
#   67969,
#   'LOUTA es el nombre artístico de Jaime Martín James, un cantante, compositor, productor, DJ y artista plástico argentino que nació en Buenos Aires el 22 de junio de 1994. Hijo de la bailarina Ana Frenkel y del director teatral Diqui James, LOUTA comenzó su carrera musical como DJ y viajó a Europa a buscar inspiración. En 2016, lanzó su primer álbum homónimo, que lo dio a conocer al público como un referente del indie argentino. En 2018, publicó su segundo álbum <a href="https://www.last.fm/music/Louta">Read more on Last.fm</a>',
#   'Wos, Paco Amoroso, Conociendo Rusia, Zoe Gotusso, Tan Bionica'],
#  ['Kerala Dust',
#   1214514,
#   95566,
#   'KERALA DUST seeks to bridge that divide between electronic music and traditional songwriting.\n\nKerala Dust was formed in London in 2016. Growing up on the sounds of CAN, The Velvet Underground and Tom Waits while spending blurry mornings in nightclubs, the band combines those disparate influences of psychedelic rock, blues and techno into one. \n\nKerala Dust are\nEdmund Kenny on vocals/electronics\nHarvey Grant on keys\nLawrence Howarth on guitar. <a href="https://www.last.fm/music/Kerala+Dust">Read more on Last.fm</a>',
#   'Stavroz, Iorie, Acid Pauli, Geju, Monoplay'],
#  ['islandman',
#   644748,
#   58358,
#   'Was born from the musical dreams of Istanbul based musician/producer Tolga Boyuk, Islandman represents a fiction character, a music persona, a dreamer composing the stories of a non -existing place…\n\nIslandman performs on stage as an electro-acoustic live trio format. Their music can be described as a unique mix of mellow electronic structures & dance beats with spacey live guitars, backed up by shamanic rhythms.\n\nThe mixing idea during the record <a href="https://www.last.fm/music/Islandman">Read more on Last.fm</a>',
#   'Oceanvs Orientalis, Viken Arman, tetouze, Populous, beyhude'],
#  ['Quantic',
#   13586432,
#   843885,
#   'Quantic is an umbrella name for UK-born, Will Holland: acclaimed producer, musician and DJ for over 15 years evolving and involving styles like Funk & Jazz to Electronic & Folk music through to Latin, Reggae, Dub & Cumbia. Holland has released over ten full-length albums internationally through the label, Tru Thoughts, ...across six different projects ranging from his DJ/Producer/Remixer moniker that has packed dance floors from Bulgaria to Buenos Aires <a href="https://www.last.fm/music/Quantic">Read more on Last.fm</a>',
#   'Guts, TM Juke, The Quantic Soul Orchestra, Nightmares on Wax, 9 Lazy 9'],
#  ['DJ Dark',
#   276163,
#   35285,
#   'Biografie\nIn 2008 lanseaza primul track produs in studioul Whiteeffect Studio ce se intituleaza “You gonna Fight” ce inregistreaza un succes neasteptat pe vremea aceea.In acelasi an o cunoaste si pe Dora care accepta sa fie vocea pentru al doilea single semnat “Dj Dark ft Dora – Someday”.\nLa inceputul anului 2010 incepe colaborarea cu postul de radio VIBE FM unde devine din ce in ce mai apreciat datorita dorintei sale de a oferi seturi cat mai pozitive ascultatorilor. <a href="https://www.last.fm/music/Dj+Dark">Read more on Last.fm</a>',
#   'Vanotek, Unklfnkl, Qodës, Monoir, Sianna'],
#  ['Cerrone',
#   2325366,
#   274869,
#   'Cerrone (full name: Jean-Marc Cerrone) (born 24 May 1952, Vitry-sur-Seine, near Paris, France) is an iconic and influential French European disco and dance pop drummer, singer, and music producer. Marc Cerrone has sold over thirty million albums. He claims, and it is often credited by others, that he was "the first" to put the kick drum (or bass drum) into the foreground of modern eurodance music.  At the age of 12, he started playing drums and listening to Otis Redding\'s songs. <a href="https://www.last.fm/music/Cerrone">Read more on Last.fm</a>',
#   'Gino Soccio, Chilly, Patrick Cowley, Chic, Space'],
#  ['MEUTE',
#   1578921,
#   105413,
#   'MEUTE is a Techno Marching Band - a dozen drummers and horn players from Hamburg/Germany who fulfil the job of a dj with their acoustic instruments. The archaic conglomerate of brass and drums creates a new genre by combining hypnotic driving techno and expressive brass band music. MEUTE detaches electronic music from the dj desk and evolves the thrust of energy on stage or directly in the crowd. No matter if in the countryside or in the club, with or without electricity – MEUTE runs. <a href="https://www.last.fm/music/Meute">Read more on Last.fm</a>',
#   'pølaroit, Zuma Dionys, Alex Christensen, Lynnic, Thylacine'],
#  ['BLOOM',
#   993742,
#   85473,
#   'There are at least thirteen bands with the name Bloom.\n\n1. A force in Australian Metalcore, Bloom combine fierce sounds and impassioned lyrics to steadily build a concrete foundation through their passionate, conceptual projects. With a catalogue that focuses on grief, love and exile, Bloom partners their deeply emotive lyrical content with surging rhythms and memorable hooks to dynamically marry harrowing concepts and captivating listening experiences. <a href="https://www.last.fm/music/Bloom">Read more on Last.fm</a>',
#   'No Home, Casey, Tapestry, Like Moths to Flames, Counterparts'],
#  ['Mijangos',
#   22108,
#   5395,
#   ' <a href="https://www.last.fm/music/Mijangos">Read more on Last.fm</a>',
#   'Silvano Del Gado, Sparrow & Barbossa, Da Le (Havana), Oreja, The Deepshakerz'],
#  ['Thievery Corporation',
#   55016966,
#   1712317,
#   'Thievery Corporation is a Washington, D.C.-based recording artist and DJ duo consisting of Rob Garza and Eric Hilton and their supporting artists. Their music style mixes elements of dub, acid jazz, Indian classical and Brazilian (such as bossa nova) with a lounge aesthetic.\n\nThievery Corporation is on the Eighteenth Street Lounge record label named after the DC club owned by Eric Hilton, but several of their singles and EP\'s appear on the 4AD and !K7 labels. <a href="https://www.last.fm/music/Thievery+Corporation">Read more on Last.fm</a>',
#   'The Funky Lowlives, Sofa Surfers, The Karminsky Experience Inc., Ursula 1000, Hird'],
#  ['Paul Kalkbrenner',
#   22449387,
#   647167,
#   'Paul Kalkbrenner (1977) is a producer, DJ and actor from Berlin, Germany. He is signed to the famous Bpitch control label founded by Ellen Allien.\n\nStarting as a trumpet player and studying music theory, Kalkbrenner later switched to electronic music. In 1999 he released his first tracks under the name of Paul dB+. As a live act, he performs using Ableton Live in combination with midi controllers and hardware synthesizers.\n\nIn 2008 he composed the sountrack for the German movie Berlin Calling in which he also is the leading actor. <a href="https://www.last.fm/music/Paul+Kalkbrenner">Read more on Last.fm</a>',
#   'Fritz Kalkbrenner, Sascha Funke, Kölsch, Marek Hemmann, NTO'],
#  ['RL Grime',
#   6133439,
#   407655,
#   'RL Grime is one of the stage names of Henry Steinway who also released music as Clockwork. He is part of WeDidIt Collective and label boss of Los Angeles\' Sable Valley.\n\nLos Angeles based producer RL Grime has risen the ranks to the forefront of what is undoubtedly the future of electronic music. He has released three studio albums, 2014\'s VOID, 2018\'s NOVA and 2023\'s triple pack PLAY.\n\n\nhttp://rlgrime.com/\nhttps://sablevalley.com/\nhttp://www.wediditcollective.com/ <a href="https://www.last.fm/music/RL+Grime">Read more on Last.fm</a>',
#   'Juelz, Boombox Cartel, Quix, Ekali, What So Not'],
#  ['Alef',
#   153142,
#   24741,
#   'This page refers to 2 acts : \nAlex Farhat, producer from Athens, Greece with mediterraneen inspirationsA quartet (Sadato - saxes / synth / compositions; Gunn - guitars; Kato - bass / synth; Ishida - drums / percussion) that casts a very wide stylistic net in a determinedly Dadaistic fashion. They have only one album, Hajime! (1987) <a href="https://www.last.fm/music/Alef">Read more on Last.fm</a>',
#   'Catching Flies, Viken Arman, beyhude, Valentin Stip, Islandman'],
#  ['Pomo',
#   518983,
#   85221,
#   'Pomo is a Canadian born multi-instrumentalist now residing in Montreal, QC, Canada.\nWith absolute vigour, Pomo has taken the electronic music scene by the collar and dragged it back onto the dance floor with dreamy synths, glittery arpeggios, buoyant beats and twangy samples. There really is only one way to describe Pomo\'s music... \n\nSunshine flavoured ice cream for the ears.\n\n <a href="https://www.last.fm/music/Pomo">Read more on Last.fm</a>',
#   'Moon Boots, Pat Lok, Midnight Pool Party, Moullinex, Chris Malinchak'],
#  ['Bomba Estéreo',
#   5063980,
#   315218,
#   'Bomba Estéreo is a (cumbia + electronic music) band formed in Bogotá,  Colombia in 2005 and led by Simón Mejía. In 2007 they released their debut album Vol. 1. \n\nCurrently the band has finished promoting its second album  Estalla throughout Europe, Latin America and the United States, and is preparing the recording of a third album.\n\nThe original lineup consists of:\nSimon Mejía, Songwriting, Bass, Loops and Backing Vocals.\nLi Saumet, Lyrics, Lead Vocals. <a href="https://www.last.fm/music/+noredirect/Bomba+Est%C3%A9reo">Read more on Last.fm</a>',
#   'Systema Solar, Mitú, ChocQuibTown, Monsieur Periné, Aterciopelados'],
#  ['Mark Alow',
#   71223,
#   12442,
#   'Spanish producer Mark Alow is an emerging talent with an ear for deep grooves and organic melodies.\n\nEarly 2018 is when Mark’s swift ascension in the scene kicked off, beginning with the Golden Tiger EP on the praised Sol Selectas label. Complete with remixes by Uner and Robbie Akbal, the track White Tusk was received with acclaim and rose through the charts before settling in the top five deep house tracks on Beatport.\n\nIn March, Mark Alow released his the Nebula EP on Solar Distance. <a href="https://www.last.fm/music/Mark+Alow">Read more on Last.fm</a>',
#   'Gab Rhome, Helly Larson, Pablo Bolivar, Guy J, Addex'],
#  ['Moby',
#   115271970,
#   3170626,
#   'Richard Melville Hall (born September 11, 1965), known professionally as Moby, is an American musician, songwriter, singer, producer, and animal rights activist. He has sold 20 million records worldwide. AllMusic considers him to be "among the most important dance music figures of the early 1990s, helping bring dance music to a mainstream audience both in the United States and the United Kingdom." After taking up guitar and piano at age nine, he played <a href="https://www.last.fm/music/Moby">Read more on Last.fm</a>',
#   'Voodoo Child, Röyksopp, Faithless, Groove Armada, Schiller'],
#  ['Peces Raros',
#   683980,
#   38530,
#   '\nPeces Raros is an argentinian band that fuses tradition with future, mixing songwriting roots with a machine lenguage. Electronic music haunted by the rock ghost.\n https://www.instagram.com/peces.raros/\n https://www.facebook.com/peces/ <a href="https://www.last.fm/music/Peces+Raros">Read more on Last.fm</a>',
#   'Él mató a un policía motorizado, Bandalos Chinos, El Zar, Paco Amoroso, Mujer Cebra'],
#  ['Leon Vynehall',
#   4303389,
#   300542,
#   'Leon Vynehall is British producer and DJ, born in Kent, in the south east of England. Vynehall\'s music combines the "percussive energy of contemporary House music" with "rich harmonies of sample-centric producers". Vynehall lists Aphex Twin, Afrika Bambaataa, Man Parrish and DJ Shadow as some of his major influences. <a href="https://www.last.fm/music/Leon+Vynehall">Read more on Last.fm</a>',
#   'Anthony Naples, Ross From Friends, Terekke, Joy Orbison, Laurence Guy'],
#  ['Rodrigo Gallardo',
#   314711,
#   40118,
#   '\n Rodrigo Gallardo has long been interested in the "folkloric traditions" of South America. El Origen is his attempt to incorporate these traditional sounds, rhythms and instrumental tropes into a contemporary electronic music setting. His original productions - all fluttering flutes, gentle acoustic guitars, warm electronics and evocative vocals are showcased on the A side, with pal and fellow Chilean Nicola Cruz. <a href="https://www.last.fm/music/Rodrigo+Gallardo">Read more on Last.fm</a>',
#   'Derrok, Satori (NL), Huaira, Vruno, Rubio'],
#  ['Fukkk Offf',
#   1668227,
#   238591,
#   'Fukkk Offf aka Bastian Heerhorst has been renowned for some time in his hometown for storming live sets in the clubs scattered around Hamburg\'s red light district. "Die sündige Meile" or "the sinful mile" as it is known has seen its walls shaked and thighs quaked by the throbbing depths of Bastian\'s big room Fukkk Offf Sound. Many a night you would witness the frustration on the faces of lonely old men as they realized that the brothels were empty. <a href="https://www.last.fm/music/Fukkk+Offf">Read more on Last.fm</a>',
#   'Boys Noize, Naeleck, Surkin, Vitalic, The Bloody Beetroots'],
#  ['Nightmares On Wax',
#   19656492,
#   1113234,
#   'Nightmares on Wax is DJ and musician George Evelyn, also known as DJ Ease (Experimental Audio Sample Expert), from Leeds, United Kingdom. The musical style is a combination of electronic sounds and hip hop beats, often regarded as "chillout". Nightmares On Wax\'s music is released on Warp Records.\n\nInitially working with Kevin Harper a.k.a Boy Wonder their first release was the massive underground hit \'Dextrous\' which sampled the as yet unknown A Guy Called Gerald\'s \'Voodoo Ray\' on their own Poverty Records label. <a href="https://www.last.fm/music/Nightmares+on+Wax">Read more on Last.fm</a>',
#   'Tosca, Kruder & Dorfmeister, Fila Brazillia, Kid Loco, Thievery Corporation'],
#  ['Monetochka',
#   1338019,
#   50378,
#   'Monetochka (Russian: Монеточка, lit.\u2009\'Little Coin\') is the stage name of Elizaveta Andreevna Gyrdymova (Russian: Елизавета Андреевна Гырдымова, born 1 June 1998 in Yekaterinburg, Russia), a Russian singer-songwriter.\nGyrdymova was born on 1 June 1998 in Yekaterinburg. From childhood, Gyrdymova enjoyed writing poetry and published her work on the site Stihi.ru as a teenager.\n\nIn 2014, she entered tenth grade at the Specialized Educational and Scientific Center of the Ural Federal University. <a href="https://www.last.fm/music/MONETOCHKA">Read more on Last.fm</a>',
#   'Moya Mishel, Alla Pugacheva, Grechka, Egor Kreed, hofmannita'],
#  ['CLUBZ',
#   1436636,
#   86743,
#   'Orlando Fernández and Coco Santos are the headmasters behind this project that originally started out in Monterrey, Nuevo León, México. This duo started back in 2013 and became significant pioneers in reviving a nostalgic 80’s and 90’s vibe inside the Mexican musical scene. Clubz came to be one of the most innovative and authentic Hispanic artists recognized internationally by music media influencers like THE FADER, Stereogum, to mention a few. <a href="https://www.last.fm/music/CLUBZ">Read more on Last.fm</a>',
#   'young tender, Little Jesus, Camilo Séptimo, Noah Pino Palo, Reyno'],
#  ['Herobust',
#   652695,
#   75614,
#   'heRobust is a pseudonym of Atlanta, GA, USA, producer Hayden Kramer.  He makes a wide range of music including downtempo glitch hop, trap and dubstep.\n\nSites: Discogs <a href="https://www.last.fm/music/heRobust">Read more on Last.fm</a>',
#   'Monxx, Panda Eyes, What So Not, Flume, The Brig'],
#  ['CA7RIEL',
#   1991374,
#   53725,
#   'Catriel Guerreiro (Buenos Aires, 5 de diciembre de 1993)1\u200b2\u200bconocido artísticamente como Ca7riel, es un músico argentino polifacético. Actualmente lleva adelante una carrera solista, a la vez que integra el dúo Ca7riel y Paco Amoroso, junto a Ulises Guerriero.\n\n\nCatriel nació en Buenos Aires, Argentina en el año 1995, en una familia de artesanos.\n\nCerca del 2011, forma la banda Astor y las Flores de Marte, junto a Ulises Guerriero en batería, Alan Alonso en voz, guitarras y samples y Felipe Brandy en voz y bajo. <a href="https://www.last.fm/music/Ca7riel">Read more on Last.fm</a>',
#   'Paco Amoroso, Ca7riel, Paco Amoroso, DJ Alex, Ca7riel & Paco Amoroso, Louta'],
#  ['MD DJ',
#   89903,
#   12847,
#   ' <a href="https://www.last.fm/music/MD+DJ">Read more on Last.fm</a>',
#   'Zeni N, Dj Dark, Dani Corbalan, Alex Menco, SERGE LEGRAN'],
#  ['deadmau5',
#   68577111,
#   1953045,
#   'Joel Thomas Zimmerman (born January 5, 1981), better known as deadmau5, is a Canadian progressive house, electro house and techno producer from Niagara Falls, Ontario. He is regarded as one of the world\'s most respected electronic music producers of modern times. In pop culture, he is known for wearing a large "mau5head" while performing at live events.\n\nThe deadmau5 discography is currently comprised of eight studio albums, eight compilation albums <a href="https://www.last.fm/music/deadmau5">Read more on Last.fm</a>',
#   'deadmau5 & Wolfgang Gartner, BSOD, kx5, Melleefresh & Deadmau5, No Mana'],
#  ['Lucky Luke',
#   2462445,
#   202014,
#   'There is more than one artist with this name, including: \n1) Lucky Luke was a Scottish indie folk band. \n2) Lucky Luke is a Lithuian artist. \n3) Lucky Luke is a German Rapper. \n\n1) Lucky Luke was a Scottish indie folk band comprising Simon Shaw, Morag Wilson, Lucy Sweet, Ian Murray, Eilidh Rodgers, Solveig Askvik, and John Hogarty. They released "Patrick The Survivor" (2005) and "Travelling For A Living" (2009). Some members went on to other bands. \n\n2) Lucky Luke is a Lithuian artist. \n\n3) Lucky Luke is a German Rapper.  <a href="https://www.last.fm/music/Lucky+Luke">Read more on Last.fm</a>',
#   'Tujamo, HVME, Vize, Lizot, Feder'],
#  ['Kermesse',
#   169337,
#   28822,
#   'Kermesse is a duo from Buenos Aires, Argentina. Pedro and Gurtz, became friends traveling and playing music with previous projects. In 2015 they found the moment to merge their ideas into a new aesthetic. \u2028 Their sound could be described as effervescent, colorful, with a catchy groove product of the fusion of electronic sounds with instruments and vocals. \u2028 They released on labels such as The Magic Movement, LNDKHN, Kamai Music, Serafin Audio, and more. <a href="https://www.last.fm/music/Kermesse">Read more on Last.fm</a>',
#   'Lagartijeando, Chancha Vía Circuito, Alexander Pierce, Ninze, Luca Musto'],
#  ['Rival Consoles',
#   6962795,
#   313756,
#   'Rival Consoles is Ryan Lee West. Born on November 1985, in Leicester, England, Ryan graduated from De Montfort University after experimenting with sound production. He made his debut Erased Tapes Records release in 2007 with the \'Vemeer\' EP. \'The Decadent\' EP would be his first release on the label as Rival Consoles.\n\nIn 2009, he featured 3 tracks on the split \'65 / Milo\' with label mates Kiasmos.  \'IO\', the first full-length release, was rereleased the same year. <a href="https://www.last.fm/music/Rival+Consoles">Read more on Last.fm</a>',
#   'Kiasmos, Jon Hopkins, Apparat, Gidge, Daniel Avery'],
#  ['Rubio',
#   770589,
#   44533,
#   'RUBIO is the personal project and artistic experiment of the renowned chilean drummer, producer and front-woman Francisca Straube. Emerges in early 2015 and mixes Pop, Hip- Hop, Electronic, Ambient and Ethnic music elements. During 2017, she came up to share - as a personal journal- a continuous series of five double singles, produced jointly with producer Pablo Stipicic and released by Jungla Music. “R”, “U”, “B”, “I”, “O” in 2018, followed by “La Llamada” and “Fábula”, embodies its first album: PEZ. <a href="https://www.last.fm/music/Rubio">Read more on Last.fm</a>',
#   'Francisco Victoria, Alex Anwandter, Marineros, Javiera Mena, Dënver'],
#  ['Poshlaya Molly',
#   1519284,
#   49614,
#   'Poshlaya Molly (Пошлая Молли)  (Vulgar Molly) is a Ukrainian band formed in 2016 by musician Kirill Timoshenko. The group is one of the most brilliant representatives of synth-punk in Ukraine, combining pop-punk with electronic music. <a href="https://www.last.fm/music/Poshlaya+Molly">Read more on Last.fm</a>',
#   'Valentin Strykalo, Vremya i Steklo, Иван Дорн, zhanulka, CLONNEX'],
#  ['Traf',
#   63321,
#   9960,
#   ' <a href="https://www.last.fm/music/Traf">Read more on Last.fm</a>',
#   'pølaroit, Petit Biscuit, Dye O, Melokind, MOKADO'],
#  ['Babasonicos',
#   1307998,
#   48536,
#   'Babasónicos\' name is based on a tribute to Hindu prophet Baba combined with the name of a popular cartoon from the \'70s. Singer Adrián Rodríguez, keyboardist Uma-T, guitarist Mariano Roger Sónico, bassist Gabo, percussionist Diego Uma, and drummer Diego Castellano recorded Pasto in 1992. That album included their hit song called "De-generación." As the popularity of this Latin rock group was growing, chances to play along with major bands came soon. <a href="https://www.last.fm/music/+noredirect/Babasonicos">Read more on Last.fm</a>',
#   'Sin datos'],
#  ['Andrew Meller',
#   67978,
#   16095,
#   'Andrew Meller is a former of 3 projects with over 80 releases behind and few top charts. \nHe literally lifting the crowd to their feet with great choice of music and unique\ntechnique. A great enthusiasm and energy that runs through his kits, not only recognized by\nmany clubs who employ him often, but also by many of his fans who regularly attend his \nperformances. Andrew Meller has already become known to many by his unique style and the way he communicate with the crowd. His sets are painted with many different sounds of <a href="https://www.last.fm/music/Andrew+Meller">Read more on Last.fm</a>',
#   'Ron Costa, Vakabular, joseph ray, Dosem, Deep Spelle'],
#  ['Las Ketchup',
#   2156000,
#   403623,
#   'Las Ketchup is a 4-girl group (previously consisting of three sisters), whose members are Lola, Pilar, Lucía and Rocio Muñoz from Córdoba in Andalucia, Spain. They are the daughters of Juan Muñoz, a flamenco guitarist known as El Tomate (The Tomato). They took their name in honor of their father\'s nickname.\n\nPrior to Rocio\'s addition to the group in 2006, the other three girls had success with their worldwide hit "Aserejé", also known as The Ketchup Song in 2002. <a href="https://www.last.fm/music/Las+Ketchup">Read more on Last.fm</a>',
#   'Los Del Rio, Sonia y Selena, In-Grid, Kaoma, Alvaro Soler'],
#  ['Peter Cat Recording Co.',
#   3170518,
#   177953,
#   'Peter Cat Recording Co. is a four-piece gypsy jazz/cabaret band formed in 2009, based in New Delhi and San Francisco. Initially started as the solo project of Suryakant Sawhney, the new lineup of the band went on to play numerous college festivals in 2010. They also played the finals of NLS Strawberry Fields, and released their debut album Sinema in January 2011. In 2012, they put out their second album Wall of Want. <a href="https://www.last.fm/music/Peter+Cat+Recording+Co.">Read more on Last.fm</a>',
#   'The F16s, Prateek Kuhad, Parekh & Singh, Ritviz, LIFAFA'],
#  ['Martin Jensen',
#   4669320,
#   446704,
#   'Martin Jensen (born 29 September 1991) is a Danish DJ and record producer best known for the 2016 single "Solo Dance". His videos feature sounds sampled from viral videos and made into tropical house mixes. He has over 10 years of experience of being club DJ, in Sunny Beach.[1] In October 2016, he was ranked 82 out of the 100 best DJs in the world by DJ Magazine. <a href="https://www.last.fm/music/Martin+Jensen">Read more on Last.fm</a>',
#   'Sam Feldt, Mike Perry, Jonas Blue, Cheat Codes, Sigala'],
#  ['Jody Wisternoff',
#   1234860,
#   130524,
#   'Jody Wisternoff’s influence and contribution to dance music cannot be overstated.\nBetween breaking through to the DMC Hip Hop finals as a fresh faced 13 year old in 1986, and putting the finishing touches to his band’s fourth studio album in 2008 a lot has happened. His early 90’s act Sub Love were one of the largest draws on the UK Rave festival circuit and his hook up with Bristol dj Nick Warren in 1994 gave us Way Out West. With big singles <a href="https://www.last.fm/music/Jody+Wisternoff">Read more on Last.fm</a>',
#   'Braxton, Marsh, Luttrell, 16Bl, Jon Gurd'],
#  ['Max Cooper',
#   4704686,
#   276411,
#   'Max Cooper has more than 50 original releases, tracks and remixes under his belt, from glitchy reinterpretations of big bands like Hot Chip and Au Revoir Simone to straight dancefloor 12"s like his breakthrough "Serie" originals and remixes for names like Agoria, Dominik Eulberg, Extrawelt, Pig and Dan, Kaiserdisco and Sasha.\n\nThe approach, meanwhile, is anything but simple. A melancholy composer whose live sets can raise blisters in a club, Cooper is as comfortable writing abstract electronica as he is writing dancefloor techno 12"s . <a href="https://www.last.fm/music/Max+Cooper">Read more on Last.fm</a>',
#   'Max Cooper & Tom Hodge, Christian Löffler, Dominik Eulberg, Weval, Kiasmos'],
#  ['Satori',
#   721841,
#   82181,
#   'There are 9 bands/artists under the name of SATORI:\n\n1) Satori (NL) House (ethno-house, progressive) music producer, DJ and musician from Holland.\n2) USA based act providing a fresh mix of reggae, bluebeat, rocksteady and ska.\n3) Shaman / ethno haos orchestra from Moldova.\n4) HC/Death band from Vyškov, Czech republic.\n5) UK based industrial / power electronics act. \n6) Hard Rock/Metal band based in the West Midlands, England.\n7) Melbourne Psychedelic/Stoner rock band.   http://www.myspace.com/satori925 <a href="https://www.last.fm/music/Satori">Read more on Last.fm</a>',
#   'MZ.412, Nordvargr, Inade, Post Scriptvm, Nocturnal Emissions'],
#  ['Vigiland',
#   2794344,
#   260774,
#   'Vigiland is a Swedish DJ/music producing house music duo, made up of Claes Remmered Persson and Otto Pettersson. They became famous with the single "UFO" which is in the style of Melbourne Bounce, a slightly more hip hop and sharper variant of progressive house music. <a href="https://www.last.fm/music/Vigiland">Read more on Last.fm</a>',
#   'Little Sis Nora, AronChupa, Mike Perry, Aronchupa & Little Sis Nora, Axwell /\\ Ingrosso'],
#  ['Paul Marmota',
#   49049,
#   6062,
#   ' <a href="https://www.last.fm/music/Paul+Marmota">Read more on Last.fm</a>',
#   'ZUTZUT, Imaabs, Beauty Brain, Manuka Honey, Lechuga Zafiro'],
#  ['ZABO',
#   291371,
#   39976,
#   'ZABO, real name Dan Szabo, is a Canadian electronic music producer. \n\nDan was introduced to electronic music at an early age. During his time at university, Dan became fascinated with music composition which led him to study audio and recording technology at the well-known OIART in London, Ontario. After several years of formal education and informal music education programs, Dan began developing his music persona “ZABO”, which was focused on a heavy electro and big-room sound.  <a href="https://www.last.fm/music/Zabo">Read more on Last.fm</a>',
#   'Social Kid, Jordan Burns, Dr. Fresch, Valentino Khan, Hairitage'],
#  ['DJ KRUSH',
#   13898508,
#   650149,
#   'DJ Krush (Hideaki Ishi) was born in 1962 in Tokyo. Gifted producer & DJ with a superb sense in mixing and composing his sound who\'s been greatly received in the international club scene. At an early age, Ishii dropped out of school, and joined a local gang, and a few years later, Yakuza. It was the movie "Wild Style" that got him into hip hop in the early 80\'s, and in 1987, he formed Krush Posse which made numerous appearances in various media as the best hip hop act in Japan. <a href="https://www.last.fm/music/DJ+Krush">Read more on Last.fm</a>',
#   'DJ Cam, DJ Krush & Toshinori Kondo, The Herbaliser, DJ Food, DJ Shadow'],
#  ['Dwin',
#   987298,
#   100253,
#   'DWIN is Daumantas Vinkevičius from Vilnius, Lithuania and founder of LITHUANIA HQ <a href="https://www.last.fm/music/Dwin">Read more on Last.fm</a>',
#   'Gaullin, LIUFO, Dynoro, KEAN DYSSO, Michael Calfan'],
#  ['Be Svendsen',
#   666144,
#   63742,
#   '2014 was the year that electronica’s cognoscenti fell for Be Svendsen. Following the success of live performances at Fusion and BOOM, the Danish musician has become a treat on the global festival scene and proponent of a uniquely organic, genre-bending sound that could best be described as ‘Tarantino Techno’. \n\n \n\nRather like Tarantino, Svendsen’s art has the distinction of being rooted in both the familiar and the obscure. The playful and the ironic. <a href="https://www.last.fm/music/Be+Svendsen">Read more on Last.fm</a>',
#   'Nu, Nhar, Alec Troniq, Laid Back, Solomun'],
#  ['Bob Moses',
#   6055303,
#   372543,
#   'Electronic duo Bob Moses play a potent hybrid of house music and lyrical pop, fusing smooth vocals and guitar licks with club beats. Emerging in 2012 with a series of well-received EPs, the duo earned commercial and critical accolades, including a Grammy nomination for the single "Tearing Me Up" off their 2015 debut Days Gone By. Battle Lines followed in 2018, and the duo\'s third studio album, The Silence in Between, arrived in 2022.\n\nBorn and bred in Brooklyn <a href="https://www.last.fm/music/Bob+Moses">Read more on Last.fm</a>',
#   'Elderbrook, Eli & Fur, ZHU, Avoure, Sultan + Shepard'],
#  ['Against All Logic',
#   6272497,
#   236320,
#   'Against All Logic, aka Nicolas Jaar, aka A.A.L is a Chilean-American house and electronic producer, composer and recording artist based out of New York.\n\nSince 2008, Nicolás Jaar has released music under various guises spanning shades of pop, ambient, noise, and club music. Among his notable works, are the albums Space Is Only Noise (2011), Pomegranates (2015) and Sirens (2016).\n\nHis "Against All Logic" alias is most known for its first (under said alias) album <a href="https://www.last.fm/music/Against+All+Logic">Read more on Last.fm</a>',
#   'Nicolas Jaar, Floating Points, Daphni, Ross From Friends, Leon Vynehall'],
#  ['Manybeat',
#   23956,
#   4515,
#   'Manybeat, cuyo nombre es: Manuel Alberto Bolívar, nace en Caracas en el año 1973 Y a los 8 años de edad ya mostraba dotes y dones musicales. A los 17 años ya era dj y a partir de los 21 años comienza a producir todo tipo de remixes y producciones musicales en todos los géneros más populares. Participando en producciones para Jlo, Gente de zona, Oscarcito y muchos más, y en la parte de generos electrónicos ha tenido colaboraciones con Robie Rivera <a href="https://www.last.fm/music/Manybeat">Read more on Last.fm</a>',
#   'Reis Belico, DJ Chus, Tambor Urbano, Dario Nunez, 3 dueños'],
#  ['WhoMadeWho',
#   6220240,
#   397679,
#   'WhoMadeWho are a Danish indie rock/dance-punk band from Copenhagen founded 2003 by Tomas Hoefding aka Bon Homme, Jeppe Kjellberg and Tomas Barfod. WhoMadeWho\'s sound has been described as "lean, yet lush and moving crisply through continents of stylistic territory." Besides a number of 12" singles and remixes for other artists, the band\'s first full release was their self-titled debut, \'WhoMadeWho\'. The majority of the tracks from this album were later reworked into acoustic form on what would become their second record, \'Green Versions\'. <a href="https://www.last.fm/music/WhoMadeWho">Read more on Last.fm</a>',
#   'Kasper Bjørke, Agoria, Hot Chip, Yuksek, SOHN'],
#  ['TroyBoi',
#   2398812,
#   223836,
#   'TroyBoi, real name Troy Henry, is a electronic music producer from South East London born 1987. He got his start making his beats standing up in his kitchen, in his studio apartment on his Mac Book and a midi keyboard. This multi-talented musician specializes in extraordinarily unique, versatile, and highly musical tracks that fuses various textures from multiple genres. TroyBoi is without a doubt one of the top up-and-coming producers in the game right now and it\'s quite clear from his composition that his influences are vast indeed. <a href="https://www.last.fm/music/TroyBoi">Read more on Last.fm</a>',
#   'Buku, Keys N Krates, Tropkillaz, Apashe, ATLiens'],
#  ['Jugurtha',
#   43202,
#   8525,
#   '1. Progressive Death/Black band from Toronto, Ontario (Canada). Got one EP so far "Empyre". \n\nhttps://jugurthametal.bandcamp.com/album/empyre\n\n2. Oriental deep house producers / band.\n <a href="https://www.last.fm/music/JUGURTHA">Read more on Last.fm</a>',
#   'Valeron, Solidmind, Kosa, Hot Oasis, tebra'],
#  ['Kink',
#   814018,
#   115102,
#   'KiNK is an Bulgarian acid techno and acid house producer, also known with his attempts in experimental styles. His his first release - "Same ol\' thing" was released by the UK label Odori and hit the house charts of several online vinyl shops.\n\nWith the support of names such as Josh Wink, Richie Hawtin, Laurent Garnier, Surgeon and Modeselektor, KiNK is rapidly gaining momentum in the electronic music industry and is proving himself as a unique and consistent producer. <a href="https://www.last.fm/music/KiNK">Read more on Last.fm</a>',
#   'Maceo Plex, Paul Johnson, Radio Slave, Chris Stussy, Batu'],
#  ['Morcheeba',
#   45597358,
#   1525068,
#   'Morcheeba is an English electronic band formed in the mid-1990s with founding members vocalist Skye Edwards and the brothers Paul and Ross Godfrey. They mix influences from trip hop, rock, folk rock and downtempo, and have produced nine regular studio albums since 1995, two of which reached the UK top ten.[1] Edwards left the band in 2003, after which the brothers used a number of singers before she rejoined in 2009. They recruit additional members for their live performances and have toured internationally. <a href="https://www.last.fm/music/Morcheeba">Read more on Last.fm</a>',
#   'The Funky Lowlives, Marsmobil, Hird, Nuspirit Helsinki, Soma Sonic'],
#  ['Tiga',
#   7505442,
#   640000,
#   'Tiga is the stage name of Montreal, Quebec, Canada-born DJ/producer Tiga James Sontag (born 1974). He graduated from Selwyn House School, a prestigious school in Westmount. Before producing music, he was involved in the promotion of rave parties in his native city during the early 1990s, also Tiga was involved in the creation of world renowned afterhours club SONA. In 1994, he opened a record store named DNA Records, and in 1998 founded his own label, Turbo Recordings. <a href="https://www.last.fm/music/Tiga">Read more on Last.fm</a>',
#   'Felix da Housecat, Simian Mobile Disco, Miss Kittin, Miss Kittin & The Hacker, Boys Noize'],
#  ['Little Dragon',
#   28763304,
#   1175853,
#   'Little Dragon is an electronic music group formed in 2006 and based in Göteborg, Sweden. The band is made up of Yukimi Nagano (vocals), Fredrick Källgren (bass), Håkan Wirenstrand (keyboards) and Erik Bodin (drums).  Their new album \'Nabuma Rubberband\' was released on May 13, 2014 on Loma Vista.  Prior to this, they released three studio albums: Little Dragon (2007), Machine Dreams (2009) and Ritual Union (2011). \n\nTheir first release was a double-A-side <a href="https://www.last.fm/music/Little+Dragon">Read more on Last.fm</a>',
#   'Goldfrapp, Neil Frances, Skinshape, Lamb, Róisín Murphy'],
#  ['George FitzGerald',
#   3367392,
#   308131,
#   'George Fitzgerald first appeared on our radar with his "Don\'t You" cut on Scuba\'s Sub:stance mix. Fast-forward a year and he\'s got his first release on Hotflush, dropping the future garage soul of "The Let Down" and a luscious dubtech gem in "Weakness". It\'s hard to escape the fact that both sides strongly remind of Joy Orbison, but that\'s a really obvious comparison to make considering that he\'s got tunes lined up for release on Doldrums. The pair <a href="https://www.last.fm/music/George+Fitzgerald">Read more on Last.fm</a>',
#   'Christian Löffler, Maribou State, Bicep, Jacques Greene, Agoria'],
#  ['JOYRYDE',
#   2403590,
#   148228,
#   'Eskimo is an English Psychedelic Trance DJ and producer, son of John Ford (also known as John Phantasm and owner of Phantasm Records). now called JOYRYDE and produces bass-heavy house music \n\nEarly career\nInspired by his father John Phantasm (and consequently the music he heard playing at home when he was young), Eskimo started producing his own music in the studio from the age of 9 but did not begin DJing worldwide until he was 13. Wrapped up in the life of DJing <a href="https://www.last.fm/music/Joyryde">Read more on Last.fm</a>',
#   'Sin datos'],
#  ['Boombox Cartel',
#   1614378,
#   165121,
#   'Blurring the lines between electronic and hip-hop with Latin influences, internationally-recognized Mexican American producer act Boombox Cartel has risen the ranks as an unparalleled force in the world of dance music. \n\nThe Boombox Cartel name spread quickly in 2015 after Jack Ü played “B2U” at Hard Fest and shortly after, every major artist was playing it live. Following the success of “B2U” came the smash single “Supernatural” with Quix and Anjulie <a href="https://www.last.fm/music/Boombox+Cartel">Read more on Last.fm</a>',
#   'RL Grime, NGHTMRE, Juelz, Ekali, Quix'],
#  ['Goldfrapp',
#   53777218,
#   1897034,
#   'Goldfrapp is an English electronic band from London, formed in 1999 which consists of Alison Goldfrapp (vocals, synthesizer) and Will Gregory (synthesizer). Despite favourable reviews and a short-listing for the Mercury Prize, the début studio album Felt Mountain did not chart highly. Goldfrapp\'s second album Black Cherry, which incorporated glam rock and synthpop sounds, was released in 2003. The album influenced the same dance-oriented sound of their third album Supernature. <a href="https://www.last.fm/music/Goldfrapp">Read more on Last.fm</a>',
#   'The Funky Lowlives, Marsmobil, Soma Sonic, Soulstice, Smith & Mighty'],
#  ['Forest Swords',
#   5834068,
#   266900,
#   'Forest Swords is one producer, Matthew Barnes, from the Wirral, Liverpool, UK. A unique blend of jagged hip-hop and R&B beats, looping guitar lines and manipulated samples, his evocative and emotional music reflects the sprawling Wirral landscape of river, coastland and woodland with all the haunting melodies of nearby city Liverpool’s enviable pop history.\n\nHis studio EP – 2010′s Dagger Paths – received huge critical acclaim. Despite it’s EP length <a href="https://www.last.fm/music/Forest+Swords">Read more on Last.fm</a>',
#   'Rival Consoles, The Haxan Cloak, Ben Frost, Blanck Mass, Lee Gamble'],
#  ['Lookas',
#   582239,
#   80976,
# ...
#   'Alvaro Soler, Los Aslándticos, David Bustamante, Marquess, Sofia Reyes'],
#  ['Baiuca',
#   555577,
#   29488,
#   ' <a href="https://www.last.fm/music/baiuca">Read more on Last.fm</a>',
#   'Tanxugueiras, Novedades Carminha, Le Parody, Carlangas, Lontreira'],
#  ['Loquillo',
#   726940,
#   52973,
#   ' <a href="https://www.last.fm/music/Loquillo">Read more on Last.fm</a>',
#   'Loquillo Y Los Trogloditas, La Guardia, Seguridad Social, Rosendo, Fito Y Fitipaldis'],
#  ['Malú',
#   1939725,
#   121455,
#   'There are at least 4 singers named Malú or Malu.\n\n1.  María \'Malú\' Lucía Sánchez (born 15 March, 1982) is a singer from Madrid, Spain. Malú was discovered at the age of 15 when she was singing at a family party. She began the recording of her first album Aprendiz in January 1998. Malú is the niece of the flamenco singer-songwriter Paco de Lucía.\n\n2. Malu is a pop singer from Amsterdam, The Netherlands. There is no accent on the letter \'u\', but scrobbles of her songs end up here due to Last. <a href="https://www.last.fm/music/+noredirect/Mal%C3%BA">Read more on Last.fm</a>',
#   'Amaia Montero, Pastora Soler, Antonio Orozco, Vanesa Martín, David Bisbal'],
#  ['David Bisbal',
#   4134277,
#   313540,
#   '\nDavid Bisbal Ferre (born June 5, 1979 in Almería, Spain) is a Latin Grammy-winning Spanish pop singer. He gained his initial fame as a runner up on the interactive reality television show Operación Triunfo produced by Television Española.\n\nHe has since released five studio albums, all of which topped the Spanish Albums Chart, in addition to recording a number of live albums. He\'s toured throughout Europe and Latin America and is now considered to be a crossover international artist. <a href="https://www.last.fm/music/David+Bisbal">Read more on Last.fm</a>',
#   'David Bustamante, Alex Ubago, Luis Fonsi, Manuel Carrasco, Cristian Castro'],
#  ['Fog Lake',
#   12528528,
#   671222,
#   'Fog Lake is the musical alias of Canadian singer-songwriter Aaron Powell. Powell began writing and recording songs in his hometown of Glovertown, Newfoundland. Powell\'s recordings have been described as "a complex collage of nebulous angst and heartfelt nostalgia". Fog Lake\'s latest full-length release, entitled Midnight Society, was released on May 19th, 2023. <a href="https://www.last.fm/music/Fog+Lake">Read more on Last.fm</a>',
#   'Pencil Legs, Teethe, fairies in our house, waveform*, Whatever, Dad'],
#  ['Dorian',
#   2702059,
#   163377,
#   'There are several artists/bands with the name Dorian:\n\n1) Dorian is a Spanish electro-pop band. They were born in 2002 in Barcelona, Spain with the common necessity to develop a sound that conjugated the tradition of the Spanish pop with contemporary electronic music.\nThe members are: Mark (voice, guitar, programmings) Belly (piano, keyboard, programmings) Bart (bass) Jordi (drums).\n\nUp to 2007 they published 2 albums: "10.000 Metrópolis"(2004) and "El futuro no es de nadie"(2006). <a href="https://www.last.fm/music/Dorian">Read more on Last.fm</a>',
#   'Lori Meyers, Love of Lesbian, Miss Caffeina, Viva Suecia, Sidonie'],
#  ['Manchester Orchestra',
#   37899413,
#   1294124,
#   'Manchester Orchestra is an American indie rock band which formed in Atlanta, Georgia in 2004. The group is currently composed of rhythm guitarist, singer/songwriter Andy Hull, lead guitarist Robert McDowell, keyboardist and percussionist Chris Freeman, bassist Jonathan Corley and drummer Tim Very. Former drummer Jeremiah Edmond parted ways with the band in January 2010 to focus on his family as well as running the band\'s record label, Favorite Gentlemen.  <a href="https://www.last.fm/music/Manchester+Orchestra">Read more on Last.fm</a>',
#   'Bad Books, All Get Out, Frightened Rabbit, mewithoutYou, Band of Horses'],
#  ['Lenny Kravitz',
#   41516447,
#   2470187,
#   'Leonard Albert "Lenny" Kravitz (born May 26, 1964. New York, USA) is an American singer-songwriter, record producer, guitarist and actor whose retro amalgam of rock, pop, funk, and even techno is inspired by such music icons as David Bowie, Jimi Hendrix and John Lennon. Like Prince and Sly Stone before him, Kravitz uses a multi-ethnic, mixed-gender backing band.\n\nKravitz plays guitar, bass, drums, keyboards, percussion, and sitar. He often plays these instruments on each recorded track <a href="https://www.last.fm/music/Lenny+Kravitz">Read more on Last.fm</a>',
#   'Prince, Prince and the New Power Generation, Seal, Prince & The Revolution, Sheryl Crow'],
#  ['Air Supply',
#   8969586,
#   798120,
#   'Air Supply is an Australian soft rock duo, consisting of Graham Russell as guitarist and singer-songwriter and Russell Hitchcock as lead vocalist. They had a succession of hits worldwide, including eight Top Ten hits in the United States, in the early 1980s. They formed in Melbourne, Australia in 1975 and have included various accompanying musicians and singers.\n\nThe two met in May 1975 while performing in the Australian production of the Andrew Lloyd Webber/Tim Rice musical, Jesus Christ Superstar. <a href="https://www.last.fm/music/Air+Supply">Read more on Last.fm</a>',
#   'David Pomeranz, Bread, England Dan & John Ford Coley, Peter Cetera, Dan Hill'],
#  ['Glenn Frey',
#   2091804,
#   339806,
#   'Glenn Lewis Frey (November 6, 1948 – January 18, 2016) was an American singer, guitarist and a founding member of the rock band Eagles. Frey was the co-lead singer and frontman for the Eagles, roles he came to share with fellow member Don Henley, with whom he wrote most of the Eagles\' material. Frey played guitar and keyboards as well as singing lead vocals on songs such as "Take It Easy", "Peaceful Easy Feeling", "Tequila Sunrise", "Already Gone", "James Dean", "Lyin\' Eyes", "New Kid in Town", and "Heartache Tonight". <a href="https://www.last.fm/music/Glenn+Frey">Read more on Last.fm</a>',
#   'Don Henley, Lobo, Mr. Mister, Eagles, Christopher Cross'],
#  ['VK Blanka',
#   849652,
#   99653,
#   ' <a href="https://www.last.fm/music/VK+Blanka">Read more on Last.fm</a>',
#   'kankakupiero, Kankaku Piero, MOB CHOIR, OxT, BURNOUT SYNDROMES'],
#  ['Rawayana',
#   2261014,
#   89849,
#   'Rawayana is a band formed in Caracas, Venezuela. Line up: BetoMonte (vocals, guitars). Tony (bass, chorus). Abeja. (guitars, chorus). Ro-ro. (drums, chorus). Toño (latin percussion). It\'s a mix of many genres like reggae, rock and acoustic. And make all the people dance to their music. It\'s made with love and for everybody! <a href="https://www.last.fm/music/Rawayana">Read more on Last.fm</a>',
#   'VINILOVERSUS, Los Mesoneros, Okills, La Vida Bohème, Cultura Profética'],
#  ['Esne Beltza',
#   139058,
#   5647,
#   'Esne Beltza: música negra desde el altavoz\n\n\nDe las horas tocando, de los viajes, de las conversaciones en las habitaciones de hotel de medio mundo durante la última gira de Fermin Muguruza surge Esne Beltza, un nuevo proyecto musical encabezado por Xabi Solano (Etzakit, 4 Itzal, Fermin Muguruza Kontrabanda, The Solanos, Afro-Basque Fire Brigada) y ocho músicos mas con la misma sed de nuevas aventuras musicales. La mayoría pertenecen a la ultima banda que formó Fermin para la última gira que ha realizado este año <a href="https://www.last.fm/music/Esne+Beltza">Read more on Last.fm</a>',
#   'Ze Esatek!, Hesian, Zea Mays, skakeitan, Ken Zazpi'],
#  ['Lauren Daigle',
#   4592093,
#   318813,
#   'Lauren Ashley Daigle, born September 9, 1991, in Lake Charles, Louisiana, is a prominent American singer-songwriter in contemporary Christian music. Raised in Lafayette, Louisiana, she was surrounded by the vibrant sounds of zydeco, blues, and Cajun music, which influenced her musical style. While Lauren always possessed a love for singing, it wasn\'t until a challenging battle with contagious cytomegalovirus at the age of 15 forced her out of high school for two years that music truly took center stage. <a href="https://www.last.fm/music/Lauren+Daigle">Read more on Last.fm</a>',
#   'Francesca Battistelli, Mandisa, Tauren Wells, Matthew West, Kari Jobe'],
#  ['Pereza',
#   4199808,
#   190349,
#   'Pereza is composed by the guitarrist Ruben (ex Buenas Noches Rose) and the bassist Leiva (ex Malahierba). In their concerts they play with another guitarrist called Pitu and a drummer called Rober.\nThey have released six albums: "Pereza", "Algo para cantar", "Animales", "Los amigos de los animales", "Aproximaciones" and "Aviones". <a href="https://www.last.fm/music/Pereza">Read more on Last.fm</a>',
#   'El Canto del Loco, Leiva, Fito Y Fitipaldis, Estopa, M-Clan'],
#  ['La Guardia',
#   334664,
#   53548,
#   'La Guardia is a Spanish pop-rock band. They were especially famous in the late 80s and early 90s, although they are still active today (after a hiatus). They have sold more than 2 million records.\n\nThe group was founded in Granada in 1983 by Manuel España (voice), Enrique Moreno "Conejo" (bass guitar) and Carlos Gilabert (keyboard), with the initial name of "La guardia del Cardenal Richelieu" ("Cardinal Richelieu\'s Guard"). They were only teenagers <a href="https://www.last.fm/music/La+Guardia">Read more on Last.fm</a>',
#   'Loquillo, Loquillo Y Los Trogloditas, Tequila, Los Secretos, M-Clan'],
#  ['Auxili',
#   121124,
#   4922,
#   ' <a href="https://www.last.fm/music/Auxili">Read more on Last.fm</a>',
#   'Atupa, Xavi Sarrià, La Fúmiga, El Diluvi, Adala'],
#  ['Manu Guix',
#   75987,
#   5917,
#   '\n\nMANU GUIX fa la seva formació musical al Conservatori Municipal de Música de Barcelona (1994) Paral·lelament reb classes de clarinet, harmonia i contrapunt, violí, cant, piano jazz, guitarra, bateria... Guix estudia un any a l’escola LIPA (Liverpool Institute for Performing Arts) on reb piano, cant, composició i arranjaments, combo, tècniques de gravació en estudi, percussió i harmonia. <a href="https://www.last.fm/music/Manu+Guix">Read more on Last.fm</a>',
#   "Gerard Quintana, Whiskyn's, Lexu's, Lax'n'Busto, Gossos"],
#  ['KANKAKU PIERO',
#   792014,
#   57898,
#   ' <a href="https://www.last.fm/music/Kankaku+Piero">Read more on Last.fm</a>',
#   'Vickeblanka, Girlfriend, みゆな, KANA-BOON, Flow'],
#  ['Miquel Abras',
#   40007,
#   4359,
#   ' <a href="https://www.last.fm/music/Miquel+Abras">Read more on Last.fm</a>',
#   "Gossos, Teràpia de Shock, Ivette Nadal, Lax'n'Busto, Blaumut"],
#  ['Black Label Society',
#   31520075,
#   825139,
#   'Black Label Society is a heavy metal band formed by former Ozzy Osbourne/Pride & Glory guitar player Zakk Wylde in Los Angeles, California in 1998. They have released ten albums to date, eight of which are studio albums. The band, aside from Wylde consists of bassist John "JD" Deservio, drummer Jeff Fabb, and rhythm guitarist Dario Lorina.\n\nThe band is not to be confused with Zakk Wylde\'s solo project (sometimes known as Book of Shadows after its only album) or with Pride & Glory, Wylde\'s southern rock band. <a href="https://www.last.fm/music/Black+Label+Society">Read more on Last.fm</a>',
#   'Zakk Wylde, Pride & Glory, Down, Ozzy Osbourne, Corrosion of Conformity'],
#  ['Muse',
#   446033281,
#   5423861,
#   'Muse are an English rock band from Teignmouth, Devon, formed in 1994. The band consists of Matt Bellamy (lead vocals, guitar, keyboards), Chris Wolstenholme (bass guitar, backing vocals), and Dominic Howard (drums). They released their debut album, Showbiz, in 1999, showcasing Bellamy\'s falsetto and a melancholic alternative rock style. Their second album, Origin of Symmetry (2001), incorporated wider instrumentation and romantic classical influences and earned them a reputation for energetic live performances. <a href="https://www.last.fm/music/Muse">Read more on Last.fm</a>',
#   'Royal Blood, Nothing But Thieves, Franz Ferdinand, Radiohead, Placebo'],
#  ['La Delio Valdez',
#   284238,
#   26852,
#   'La Delio Valdez es una orquesta de cumbia nacida en Buenos Aires, Argentina, en el año 2009. Posee una sonoridad variada que combina recursos de otras músicas; tradición andina, salsa, rock, jazz o reggae para dar lugar a un estilo que es a la vez tradicional y moderno. Luego de tres álbumes editados y nueve años de recorrido la orquesta Delio Valdez se complace en presentar su cuarta producción discográfica, Sonido Subtropical, disco que marca un hito en la historia artística de la orquesta. <a href="https://www.last.fm/music/La+Delio+Valdez">Read more on Last.fm</a>',
#   'Los Palmeras, Gilda, Soledad, Leo Mattioli, Ráfaga'],
#  ['El Kuelgue',
#   1615589,
#   48038,
#   'El Kuelgue was formed in Buenos Aires, Argentina in the year 2004, as the result of a lyrical and musical pursuit which main force is improvisation.\nFrom the beginning, they’ve played in many different stages in Buenos Aires and surroundings, and performing also on radio and television.\nIn three years, El Kuelgue has performed with argentinian artists like Javier Calamaro, Gillespie, Horacio Fontova,  Pablo Dacal ,  Venlucia , Liliana Herrero  and Alejandro Franov , among others. <a href="https://www.last.fm/music/El+Kuelgue">Read more on Last.fm</a>',
#   'Conociendo Rusia, Gauchito Club, El Zar, Nafta, Zoe Gotusso'],
#  ['Mumford & Sons',
#   121613395,
#   2442974,
#   'Mumford & Sons is an English folk rock band formed in London in 2007. The band consists of Marcus Mumford (lead vocals, electric guitar, acoustic guitar, drums), Ben Lovett (vocals, keyboards, piano), and Ted Dwane (vocals, bass guitar, double bass). Banjo player Winston Marshall left the band in 2021. \n\nMumford & Sons has released four studio albums: Sigh No More (2009), Babel (2012), Wilder Mind (2015), and Delta (2018). Sigh No More peaked at number two on the UK Albums Chart and the Billboard 200 in the US <a href="https://www.last.fm/music/Mumford+&+Sons">Read more on Last.fm</a>',
#   "The Lumineers, Of Monsters and Men, Vance Joy, Marcus Mumford, Bear's Den"],
#  ['Zoé',
#   18851194,
#   374488,
#   'There are, at least, three artists known as Zoé: 1) A Mexican rock band. 2) An aka of Zoë Pollock (also, aka Zoë). 3) A French-speaking variétés françaises singer.\n\n1) A Mexican rock band, that\'s not not afraid of experimenting, with a modern sound, an eclectic style, some British influences & overall, their music\'s sophisticated without loss of rock energy. Their lyrics cover many subjects / feelings, with the same level of sophistication that their music shows, plus honesty. <a href="https://www.last.fm/music/+noredirect/Zo%C3%A9">Read more on Last.fm</a>',
#   'León Larregui, Enjambre, Caifanes, DLD, Porter'],
#  ['Welshly Arms',
#   2836058,
#   236625,
#   'Hailing from Cleveland, Ohio, blues/rock band Welshly Arms is comprised of Jimmy Weaver bass guitar, Mikey Gould drums, Brett Lindemann keys, and Sam Getz guitar and vocals. \n\nWelshly Arms owes its unique sound to the collective influences of rhythm and soul, rock and roll, and a hint of classic jazz/blues. From Jimi Hendrix to The Temptations; from Otis Redding to Howlin’ Wolf, the band’s love affair with retro and contemporary work brings a new sound with songs like “Two Seconds Too Late” and “The Touch”. <a href="https://www.last.fm/music/Welshly+Arms">Read more on Last.fm</a>',
#   'Kaleo, Black Pistol Fire, The Blue Stones, Two Feet, Dan Owen'],
#  ['Bunbury',
#   1916457,
#   67842,
#   ' <a href="https://www.last.fm/music/+noredirect/Bunbury">Read more on Last.fm</a>',
#   'Sin datos'],
#  ['Florence + The Machine',
#   268582118,
#   3712400,
#   'Florence + the Machine are a London, UK, pop band led by singer-songwriter Florence Welch and formed in 2007.  The band consists of:  Florence Welch (vocals), Robert Ackroyd (guitar), Isabella Summers (aka Isa Machine - keyboards), Tom Monger (harp), Mark Saunders (bass, percussion), Christopher Lloyd Hayden (drums, backing vocals), Rusty Bradshaw (keyboard, backing vocals) and Sam White (backing vocals).  \n\nLead singer, Florence Welch, was an art-college drop-out <a href="https://www.last.fm/music/Florence+%252B+the+Machine">Read more on Last.fm</a>',
#   'Lorde, Hozier, Marina & the Diamonds, HAIM, Marina'],
#  ...]

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab', host='127.0.0.1', database='proyecto_spoti')

# %%
cursor = cnx.cursor()

# %%
query = """
INSERT INTO resultados_artistas_lastfm (Artista, Reproducciones, Oyentes, Biografía, Artistas_Similares)
VALUES (%s, %s, %s, %s, %s);
"""

cursor.executemany(query, resultados_artistas)

cnx.commit()

# %%
#2
df_pistas = pd.read_csv('./CSV/20000_pistas.csv')

# %%
df_pistas.fillna('Sin datos', inplace=True)

# %%
resultados_pistas = df_pistas.values.tolist()

# %%
resultados_pistas
# Out:
# [['DJ Snake',
#   'Taki Taki (with Selena Gomez, Ozuna & Cardi B)',
#   'Taki Taki (with Selena Gomez, Ozuna & Cardi B)',
#   2018,
#   'electronic',
#   '4w8niZpiMy6qz1mntFA5uM',
#   70],
#  ['Maribou State',
#   'Vale',
#   'Kingdoms In Colour',
#   2018,
#   'electronic',
#   '58FsmlVRQxpjFmXF8vSKMT',
#   64],
#  ['Xinobi',
#   'Far Away Place - Rampa Remix',
#   'Far Away Place (Rampa Remix)',
#   2018,
#   'electronic',
#   '4SpESjSScmJyuMamD9MKOL',
#   61],
#  ['Rhye',
#   'Song For You',
#   'Blood',
#   2018,
#   'electronic',
#   '0BfLvshnvJldGROufmYCrv',
#   53],
#  ['Rhye',
#   'Feel Your Weight - Poolside Remix',
#   'Blood Remixed',
#   2018,
#   'electronic',
#   '1hgX0ZmmP7IRRjUFCIBrnQ',
#   60],
#  ['Ash',
#   'Sing It Back (feat. Naila)',
#   'Sing It Back (feat. Naila)',
#   2018,
#   'electronic',
#   '2UhRf78iodPFuJa7TGMSFn',
#   65],
#  ['Guy Gerber',
#   'What To Do - &ME Remix',
#   'What to Do (Remixes)',
#   2018,
#   'electronic',
#   '3PpvhYXmJdfoxeXGWJmeas',
#   55],
#  ['Fatboy Slim',
#   'Praise You (Purple Disco Machine Remix) (Radio Edit)',
#   'Praise You (Purple Disco Machine Remix)',
#   2018,
#   'electronic',
#   '6RzRRbZxWWFm7ih6djhUzx',
#   53],
#  ['Maribou State',
#   'Nervous Tics',
#   'Kingdoms In Colour',
#   2018,
#   'electronic',
#   '2oJ8Il24SIiDCJv39RYzPp',
#   60],
#  ['Thom Yorke',
#   'Suspirium',
#   'Suspiria (Music for the Luca Guadagnino Film)',
#   2018,
#   'electronic',
#   '4Y1igB1GDncJvt7ezbV3cW',
#   55],
#  ['El Búho',
#   'Cumbia Sobre el Mar - El Búho Remix',
#   'Tributaries: A Remix Album (El Búho Remixes)',
#   2018,
#   'electronic',
#   '4TobIFLwvzPSraqUQBEZUI',
#   49],
#  ['Gaullin',
#   'Moonlight',
#   'Moonlight',
#   2018,
#   'electronic',
#   '0A5gdlrpAuQqZ2iFgnqBFW',
#   57],
#  ['Fatboy Slim',
#   'Right Here Right Now (Radio Edit) (CamelPhat Remix)',
#   'Right Here Right Now (CamelPhat Remix)',
#   2018,
#   'electronic',
#   '5cqAAt8rWLNrqhG5Otk6Jp',
#   50],
#  ['Rhye', 'Taste', 'Blood', 2018, 'electronic', '6GbWNeR3P9MTCmSyPVHgb1', 51],
#  ['BICEP',
#   'Opal - Four Tet Remix',
#   'Opal (Four Tet Remix)',
#   2018,
#   'electronic',
#   '3VtTuQ6lypMoOBcm6VMzdh',
#   52],
#  ['Jean-Michel Jarre',
#   'Equinoxe, Pt. 5',
#   'Planet Jarre (Deluxe-Version)',
#   2018,
#   'electronic',
#   '0w6SpWTvf5i70VxgArASBB',
#   44],
#  ['Adam Beyer',
#   'Your Mind',
#   'Your Mind',
#   2018,
#   'electronic',
#   '5NZdurYcFYOg3s2YyzeVgE',
#   46],
#  ['Nicolas Godin',
#   'Les rues de Paris',
#   'Au service de la France',
#   2018,
#   'electronic',
#   '5Cfz0DCrcFpISyvDHBWy9f',
#   52],
#  ['Califato ¾',
#   "L'ambôccá",
#   "L'ambôccá",
#   2018,
#   'electronic',
#   '7aL9cpCx5k0jfnusobGk3h',
#   26],
#  ['Maribou State',
#   'Glasshouses',
#   'Kingdoms In Colour',
#   2018,
#   'electronic',
#   '7isVqPzG3R5ni6IM4YG0sv',
#   55],
#  ['Rebūke',
#   'Along Came Polly',
#   'Along Came Polly',
#   2018,
#   'electronic',
#   '6fL2wAZuNKGpze9E3SINnW',
#   50],
#  ['Novalima',
#   'Machete',
#   'Afro',
#   2018,
#   'electronic',
#   '68mXF4xBYqzdzqhTsJTuy1',
#   40],
#  ['LOUTA',
#   'AYER TE VI (feat. Zoe Gotusso)',
#   'ENCHASTRE',
#   2018,
#   'electronic',
#   '7gfyrnHMieXMjIW4n2p5wf',
#   52],
#  ['Kerala Dust',
#   'The Chain',
#   'The Chain',
#   2018,
#   'electronic',
#   '7IctzNEJucIBzkAWYg6np2',
#   49],
#  ['islandman',
#   'Night Wind',
#   'Rest in Space',
#   2018,
#   'electronic',
#   '7afB9uuN1t1UQArknKHaBh',
#   46],
#  ['Quantic',
#   'Cumbia Sobre El Mar',
#   'The Power of the Latin Music',
#   2018,
#   'electronic',
#   '7KooLjzPsWw4TT12acawEB',
#   43],
#  ['Maribou State',
#   "Beginner's Luck",
#   'Kingdoms In Colour',
#   2018,
#   'electronic',
#   '6adjXENHRzh4uyVziFlVGm',
#   53],
#  ['DJ Dark',
#   'Crazy (feat. Martova)',
#   'Crazy',
#   2018,
#   'electronic',
#   '3eZ7giMTVT6oa0u4BvCrCQ',
#   41],
#  ['Cerrone',
#   'Supernature (Instrumental CLIMAX edit)',
#   'Supernature (instrumental)',
#   2018,
#   'electronic',
#   '7nIsxHK8t1p215mXLpZgbh',
#   46],
#  ['MEUTE',
#   'Hey Hey',
#   'Hey Hey',
#   2018,
#   'electronic',
#   '5Ix1TtnsaCMcDjn3WAKYQE',
#   43],
#  ['BLOOM',
#   'Earth Breath',
#   'El Mundo EP, Pt. 2',
#   2018,
#   'electronic',
#   '63S0g1NOuVCQuWjtyCOHyf',
#   47],
#  ['Maribou State',
#   'Feel Good',
#   'Kingdoms In Colour',
#   2018,
#   'electronic',
#   '3PURbsY67tLMyausOABtit',
#   52],
#  ['Jean-Michel Jarre',
#   'Magnetic Fields, Pt. 2',
#   'Planet Jarre (Deluxe-Version)',
#   2018,
#   'electronic',
#   '0mUEP5UIlGCS71xRVNa24u',
#   38],
#  ['Mijangos',
#   'Aqui Se Baila - Afro Latin Mix',
#   'Aqui Se Baila (Afro Latin Mix)',
#   2018,
#   'electronic',
#   '6jo8xMFaWUqRzqb9WisxAS',
#   36],
#  ['Thievery Corporation',
#   'San San Rock',
#   'Treasures From The Temple',
#   2018,
#   'electronic',
#   '0tutwq4hC8qFaLvLb1rEFQ',
#   46],
#  ['Paul Kalkbrenner',
#   'Part Four',
#   'Parts of Life',
#   2018,
#   'electronic',
#   '3pQK5lgb8S01XeIWwHRSLH',
#   43],
#  ['Maribou State',
#   'Kingdom',
#   'Kingdoms In Colour',
#   2018,
#   'electronic',
#   '46SpOq8ojlVUBrgGnUzUlV',
#   50],
#  ['RL Grime',
#   'UCLA',
#   'NOVA',
#   2018,
#   'electronic',
#   '0r8RKKIc4C8G6J9HAHzpaR',
#   59],
#  ['Alef',
#   'Sol',
#   'Sol y Luna',
#   2018,
#   'electronic',
#   '4FlR74PQh9SUnxDyFkoK1a',
#   45],
#  ['Pomo',
#   'Intoxicated',
#   'Intoxicated',
#   2018,
#   'electronic',
#   '2JRtD3QjOULLeguptl6riM',
#   46],
#  ['Califato ¾',
#   'Clabo y Canela',
#   "L'ambôccá",
#   2018,
#   'electronic',
#   '0GjIAlQr0oaRbxGyJPwjWJ',
#   22],
#  ['Bomba Estéreo',
#   'Soy Yo (feat. Doozie & MOJJO) - Doozie & MOJJO Remix',
#   'Soy Yo (feat. Doozie & MOJJO) [Doozie & MOJJO Remix]',
#   2018,
#   'electronic',
#   '4AeFY5aK38DimaWgp4uRJg',
#   29],
#  ['Rhye',
#   'Feel Your Weight',
#   'Blood',
#   2018,
#   'electronic',
#   '6bRVkUr1fyZVX4XwQ4RpaR',
#   43],
#  ['Ash',
#   'Give a Little (feat. Naila)',
#   'Give a Little (feat. Naila)',
#   2018,
#   'electronic',
#   '5TjdmkuqqjkyIIVuDqyFPE',
#   49],
#  ['Mark Alow',
#   'Trip To The Lonely Planet',
#   'Nebula EP',
#   2018,
#   'electronic',
#   '3AoPhInlcd98u7Z1vmwHdk',
#   45],
#  ['Rhye',
#   'A Whiter Shade Of Pale - Recorded at Spotify Studios NYC',
#   'Spotify Singles',
#   2018,
#   'electronic',
#   '6AcYLHkLDFn6qcZiPS6xNc',
#   41],
#  ['Moby',
#   'This Wild Darkness - Edit',
#   'This Wild Darkness - Edit',
#   2018,
#   'electronic',
#   '5ivnEtHX6OExzDKUWA4AE1',
#   33],
#  ['Quantic',
#   'Hotline Bling',
#   'Hotline Bling',
#   2018,
#   'electronic',
#   '7p6CgRGbeR6WyidudAzbsf',
#   39],
#  ['Peces Raros',
#   'No Van a Parar',
#   'Anestesia',
#   2018,
#   'electronic',
#   '1GLYsZMbHm72Uy2QvzdgDQ',
#   47],
#  ['Leon Vynehall',
#   'Movements (Chapter III)',
#   'Nothing Is Still',
#   2018,
#   'electronic',
#   '1OD2YXIOmfYmBAYfV1maRV',
#   46],
#  ['Rodrigo Gallardo',
#   'El Abuelo - Los Suruba & Marcelo Burlon Remix',
#   'El Abuelo',
#   2018,
#   'electronic',
#   '6FpXQA9yfqvf6oVnhdnLP1',
#   40],
#  ['Leon Vynehall',
#   'Birds On The Tarmac (Footnote III)',
#   'Nothing Is Still',
#   2018,
#   'electronic',
#   '5AdcWcvRVnQvFtJ90A2XUK',
#   45],
#  ['Rhye',
#   'Summer Days - Roosevelt Remix',
#   'Blood Remixed',
#   2018,
#   'electronic',
#   '3eM70BLTVSo6SLOS3vazXp',
#   44],
#  ['Fukkk Offf',
#   'Bang Your Head - Naeleck & KATFYR Remix',
#   'Bang Your Head',
#   2018,
#   'electronic',
#   '0HdgslFKTE3hi2lCdOf2GJ',
#   44],
#  ['Nightmares On Wax',
#   'Typical',
#   'Shape The Future',
#   2018,
#   'electronic',
#   '7pxGYI6grdtrh3M2IGuvvE',
#   46],
#  ['Monetochka',
#   'Каждый раз',
#   'Раскраски для взрослых',
#   2018,
#   'electronic',
#   '4IjiY0sShCYUEEoOSEwsgY',
#   55],
#  ['CLUBZ',
#   'Palmeras',
#   'Destellos',
#   2018,
#   'electronic',
#   '6yAdoDH69y3N0MicAczpVp',
#   50],
#  ['Herobust',
#   'Move Mint - VIP',
#   'Vertebreaker (Remixes)',
#   2018,
#   'electronic',
#   '5RRpWmpLVnZPukWYaedmsa',
#   40],
#  ['CA7RIEL',
#   'No Aterrizó',
#   'LIVRE',
#   2018,
#   'electronic',
#   '78NAaYSf1p0iDhzVPae9dR',
#   39],
#  ['Monetochka',
#   'Нимфоманка',
#   'Раскраски для взрослых',
#   2018,
#   'electronic',
#   '5Ni187gYCgJG90rGfMX7CY',
#   54],
#  ['MD DJ',
#   'X-Mas Time',
#   'X-Mas Time',
#   2018,
#   'electronic',
#   '7BSX1hn9fPstxt5lz6QCMV',
#   43],
#  ['deadmau5',
#   'Monophobia',
#   'mau5ville: Level 1',
#   2018,
#   'electronic',
#   '1mekHae3Rj2GQPM670FRJV',
#   51],
#  ['Thievery Corporation',
#   'Voyage Libre',
#   'Treasures From The Temple',
#   2018,
#   'electronic',
#   '1FOnlQtwGRGJx0p2lZxWZ0',
#   41],
#  ['Adam Beyer',
#   'Your Mind - Radio Edit',
#   'Your Mind (Radio Edit)',
#   2018,
#   'electronic',
#   '55w4mBcYYdPHV26kCC6CqO',
#   38],
#  ['Lucky Luke',
#   'Drüg',
#   'Drüg',
#   2018,
#   'electronic',
#   '5Q5TNh4wr6CPoXKrI2H6gx',
#   47],
#  ['Kermesse',
#   'Sunday Glide',
#   'Kermesse',
#   2018,
#   'electronic',
#   '72Qac2FQd9e21XCibSOhfY',
#   42],
#  ['Rival Consoles',
#   "Dreamer's Wake",
#   'Persona',
#   2018,
#   'electronic',
#   '320ePMZ8X0ugeffZk0wNzY',
#   44],
#  ['Rubio',
#   'Hacia el Fondo',
#   'Pez',
#   2018,
#   'electronic',
#   '1TmhcMiKugkz7bfryEJGR3',
#   41],
#  ['Poshlaya Molly',
#   'ПОРНХАБ КРИСМАС КЛАБ',
#   'ОЧЕНЬ СТРАШНАЯ МОЛЛИ 3, Ч. 1',
#   2018,
#   'electronic',
#   '5jgFvROeP9DlLl9dMHQEtw',
#   57],
#  ['Rhye',
#   'Waste - RY X Remix',
#   'Blood Remixed',
#   2018,
#   'electronic',
#   '08HR9PoLSeovgXWvJEZrvi',
#   43],
#  ['Traf',
#   'Dissociative',
#   'Dissociative',
#   2018,
#   'electronic',
#   '4oNnLEVCRyD3Into7UwOKy',
#   44],
#  ['Babasonicos',
#   'Ingrediente',
#   'Discutible',
#   2018,
#   'electronic',
#   '6M6aCePRkHqmQsUGa6BegN',
#   49],
#  ['CLUBZ',
#   'Nagano',
#   'Destellos',
#   2018,
#   'electronic',
#   '5qTnlwbe18VRvDJQYAreGW',
#   49],
#  ['Rhye',
#   'Softly - Mahogany Sessions',
#   'Softly / Please (Mahogany Sessions)',
#   2018,
#   'electronic',
#   '3TRleR2FHWPDWHKQf9P66X',
#   30],
#  ['Andrew Meller',
#   'Godfather’s Dance',
#   "Godfather's Dance",
#   2018,
#   'electronic',
#   '5gtnqo6ustcevImEhYYwAn',
#   36],
#  ['Rhye', 'Hymn', 'Hymn', 2018, 'electronic', '0jsFjONniYrNw6wD9e9bgs', 46],
#  ['Las Ketchup',
#   'Aserejé (2018 Radio Mix)',
#   'Aserejé (2018 Radio Mix)',
#   2018,
#   'electronic',
#   '3ZT9yfaYbpPbFFfYUJjVI8',
#   38],
#  ['Peter Cat Recording Co.',
#   'Portrait of a Time',
#   'Portrait of a Time: 2010-2016',
#   2018,
#   'electronic',
#   '0tpaTQ94O5G2lEhv9CuEFb',
#   43],
#  ['Martin Jensen',
#   "Somebody I'm Not",
#   "Somebody I'm Not",
#   2018,
#   'electronic',
#   '60dLzTKOP5Q37wThC9VVjB',
#   41],
#  ['Jody Wisternoff',
#   'The Bridge - Chicane Rework',
#   'Sun:Sets 2018 (Selected by Chicane)',
#   2018,
#   'electronic',
#   '23S3VBhXxJBGYs8MCzygpb',
#   42],
#  ['Rhye',
#   'Stay Safe',
#   'Blood',
#   2018,
#   'electronic',
#   '2s4z1J7yMhMYtSLgRxzQwq',
#   44],
#  ['Guy Gerber',
#   'What To Do',
#   'What to Do EP',
#   2018,
#   'electronic',
#   '0dWmUCTIBA6UOVjCWtbodc',
#   40],
#  ['Poshlaya Molly',
#   'Райские цветы',
#   'Грустная девчонка с глазами как у собаки',
#   2018,
#   'electronic',
#   '1DSCMhnFgL4BVI6D8fJJ8a',
#   57],
#  ['Max Cooper',
#   'Lovesong',
#   'One Hundred Billion Sparks',
#   2018,
#   'electronic',
#   '4DXwafDnkO9OakL5Q6y8o2',
#   42],
#  ['Satori', 'Yam', 'Yam', 2018, 'electronic', '4vPinL4Ov4ZX2THDVCNkX0', 40],
#  ['CA7RIEL',
#   'Vibra Alta',
#   'LIVRE',
#   2018,
#   'electronic',
#   '2qC12kW3NC8wN7Xhhpi370',
#   38],
#  ['Vigiland',
#   'Be Your Friend\u202c\u202c',
#   'Be Your Friend',
#   2018,
#   'electronic',
#   '2mSIu1ZPo22Ihx3EwS4E6h',
#   47],
#  ['Paul Kalkbrenner',
#   'Part Eleven',
#   'Parts of Life',
#   2018,
#   'electronic',
#   '6MI7XPygeiQlQ4lN9I2b5X',
#   38],
#  ['Jean-Michel Jarre',
#   'Souvenir de Chine',
#   'Planet Jarre (Deluxe-Version)',
#   2018,
#   'electronic',
#   '6K5FhSqMfTMI0el4Nu8Sq0',
#   33],
#  ['Poshlaya Molly',
#   'Все хотят меня поцеловать',
#   'Грустная девчонка с глазами как у собаки',
#   2018,
#   'electronic',
#   '0rqe1Pt1EGu0VDAqPupREU',
#   56],
#  ['Ash',
#   'Daydream',
#   'Daydream',
#   2018,
#   'electronic',
#   '3MMORRC7FoTjlKNrI6hvgU',
#   45],
#  ['Paul Marmota',
#   'Mercurio',
#   'Zona',
#   2018,
#   'electronic',
#   '4urS8frKH9Qsf16aEXsmRE',
#   19],
#  ['ZABO',
#   'Breathe',
#   'Breathe',
#   2018,
#   'electronic',
#   '1ME8Thb5mDmBYTI3I5f3uJ',
#   44],
#  ['DJ KRUSH',
#   'Kemuri',
#   'The Man From Mo’ Wax (Original Motion Picture Soundtrack)',
#   2018,
#   'electronic',
#   '2mxTWNaUEHwdedwdS9KYcW',
#   39],
#  ['Dwin',
#   'Sweet Dreams',
#   'Sweet Dreams',
#   2018,
#   'electronic',
#   '24J3dVpDXHznrOCZBGvHut',
#   45],
#  ['Be Svendsen',
#   'Andromeda',
#   'Between a Smile and a Tear',
#   2018,
#   'electronic',
#   '4pKcy4dZzal1PTAOBGWr8N',
#   41],
#  ['Bob Moses',
#   'Enough to Believe',
#   'Battle Lines',
#   2018,
#   'electronic',
#   '0fDf7Fo4Lb6DA1mmKibSNc',
#   43],
#  ['Rodrigo Gallardo',
#   'El Abuelo',
#   'El Abuelo',
#   2018,
#   'electronic',
#   '1cmjjbzi9Hqe6IgHbB7gBp',
#   38],
#  ['Against All Logic',
#   'Now U Got Me Hooked',
#   '2012 - 2017',
#   2018,
#   'electronic',
#   '3BPL6mtTSsXI3Yk4kBX6Yh',
#   42],
#  ['Paul Kalkbrenner',
#   'Part Six',
#   'Part Six',
#   2018,
#   'electronic',
#   '4mz5sOi3htRQVIz5V067OH',
#   35],
#  ['Manybeat',
#   'Mamasota',
#   'Mamasota',
#   2018,
#   'electronic',
#   '2jvx5oEiwOEiTP03OpkCuF',
#   30],
#  ['Paul Kalkbrenner',
#   'Part One',
#   'Parts of Life',
#   2018,
#   'electronic',
#   '2B5Y0umaS372GZsQf2Q601',
#   36],
#  ['Califato ¾',
#   'Açeitunitâ Negrâ',
#   "L'ambôccá",
#   2018,
#   'electronic',
#   '1gceAYS75G8joXiKZpPqYs',
#   17],
#  ['Rhye',
#   'Phoenix',
#   'Blood',
#   2018,
#   'electronic',
#   '66ESAYFSvXY16Lo97CtwU2',
#   39],
#  ['Bob Moses',
#   'Battle Lines',
#   'Battle Lines',
#   2018,
#   'electronic',
#   '0ErpngN7msRMzOybuOj4X6',
#   34],
#  ['Lucky Luke',
#   'Wonderwall',
#   'Wonderwall',
#   2018,
#   'electronic',
#   '3xJEu7OdZcjeX8iX3pvODL',
#   43],
#  ['Fatboy Slim',
#   'Right Here, Right Now - Friction & Killer Hertz Remix',
#   'Right Here, Right Now (Friction & Killer Hertz Remix)',
#   2018,
#   'electronic',
#   '0JIzCPy8H7PJYHVIW4N6zd',
#   34],
#  ['WhoMadeWho',
#   'Neighbourhood',
#   'Through the Walls',
#   2018,
#   'electronic',
#   '1KXQGi1hQcrRd3jA0LSMUh',
#   38],
#  ['Rhye',
#   'Count To Five - Tensnake Remix',
#   'Blood Remixed',
#   2018,
#   'electronic',
#   '3ASNOiJ3mAsY6wQ57liJQd',
#   39],
#  ['TroyBoi',
#   'Say Yeah',
#   'V!BEZ, Vol. 2',
#   2018,
#   'electronic',
#   '7vBqDxT6CcJhnOCRfM9Wvi',
#   45],
#  ['Rubio',
#   'Seres Invisibles',
#   'Pez',
#   2018,
#   'electronic',
#   '13jnICeB4esdhHZDvSatNm',
#   35],
#  ['Jugurtha',
#   'Sophonisbe - Sahale Remix',
#   'Sophonisbe',
#   2018,
#   'electronic',
#   '44288Pd23qyQs0FyCqti8L',
#   39],
#  ['Kink',
#   'Leko - Session Victim Remix',
#   'Leko Remixes',
#   2018,
#   'electronic',
#   '18nGprzEucUO4FF768lLhe',
#   36],
#  ['Babasonicos',
#   'La Pregunta',
#   'Discutible',
#   2018,
#   'electronic',
#   '4PxOR5geaJtZFe4Q3I115t',
#   46],
#  ['CLUBZ',
#   'Popscuro',
#   'Destellos',
#   2018,
#   'electronic',
#   '3N0lemfma0XQAlkueBbwev',
#   49],
#  ['Satori',
#   'Bad Looking Trouble - Hraach Remix',
#   'Ibiza Sunset Dreams, Vol. 4 (Compiled by DJ Zappi)',
#   2018,
#   'electronic',
#   '23ekqA205lswbljhT5XxwH',
#   38],
#  ['Morcheeba',
#   'Find Another Way',
#   'Blaze Away',
#   2018,
#   'electronic',
#   '1CikWxgqAiJgY2aQEGn8C4',
#   34],
#  ['Tiga',
#   'Sunglasses at Night',
#   'Sunglasses at Night',
#   2018,
#   'electronic',
#   '6nOYKhskIZXcfdFe8eVmOi',
#   36],
#  ['Against All Logic',
#   'Cityfade',
#   '2012 - 2017',
#   2018,
#   'electronic',
#   '3ClchMcD2JCnSfCL6xum9Y',
#   41],
#  ['Little Dragon',
#   'Lover Chanting - Edit',
#   'Lover Chanting (Jayda G Remix)',
#   2018,
#   'electronic',
#   '3ceihRUljV1eSM1plIjsB6',
#   42],
#  ['Mark Alow',
#   'White Tusk - Original',
#   'Golden Tiger',
#   2018,
#   'electronic',
#   '5MNG30HnVmfLYxkKe5n1Zn',
#   35],
#  ['George FitzGerald',
#   'Passing Trains',
#   'All That Must Be',
#   2018,
#   'electronic',
#   '01oZjrRICAL5l0sSFqpb5D',
#   39],
#  ['Ash',
#   'Big in Japan',
#   'Big in Japan',
#   2018,
#   'electronic',
#   '49uuX76cJwR4lrUFnDJTZV',
#   44],
#  ['DJ Dark',
#   'Ederlezi (feat. Dikanda)',
#   'Ederlezi (feat. Dikanda)',
#   2018,
#   'electronic',
#   '1LdmFlLhYJiW7BlE7PzGfR',
#   40],
#  ['Gaullin',
#   'All the Things',
#   'All the Things',
#   2018,
#   'electronic',
#   '0OsAQfkwbPwT0Jv7g3oTqh',
#   46],
#  ['Fukkk Offf',
#   'Pacific Coast Highway',
#   'Pacific Coast Highway',
#   2018,
#   'electronic',
#   '34nixLtq739l1cY1eGCSW0',
#   40],
#  ['JOYRYDE',
#   'AGEN WIDA',
#   'AGEN WIDA',
#   2018,
#   'electronic',
#   '35V6qXUDCvwZdmbKe5PlPG',
#   43],
#  ['Nicolas Godin',
#   'Marie Jo',
#   'Au service de la France',
#   2018,
#   'electronic',
#   '0hj6LlttTZizCt3hbMC2cB',
#   38],
#  ['Novalima',
#   'Macaco - Novalima Remix',
#   'Karimba',
#   2018,
#   'electronic',
#   '7GZY4oiuoXyhW7e0n02tXG',
#   28],
#  ['Tiga',
#   'Sunglasses at Night - 12" Version',
#   'Sunglasses at Night',
#   2018,
#   'electronic',
#   '1d2jOoKeBeFcnNGpqTOveU',
#   33],
#  ['Paul Kalkbrenner',
#   'Part Ten',
#   'Parts of Life',
#   2018,
#   'electronic',
#   '0xvlFJilJpOBRySCwtSlnU',
#   35],
#  ['Boombox Cartel',
#   'Moon Love',
#   'Moon Love',
#   2018,
#   'electronic',
#   '5LCaw96SsbpHAQFAcbFwbI',
#   42],
#  ['Kerala Dust',
#   'Maria',
#   "Francesca's Frames EP",
#   2018,
#   'electronic',
#   '2vOfifh09XV8vAEj0dffVW',
#   39],
#  ['Goldfrapp',
#   'Ocean',
#   'Silver Eye: Deluxe Edition',
#   2018,
#   'electronic',
#   '0J6IuDbT6oAhbfhw381zmz',
#   34],
#  ['Poshlaya Molly',
#   'Буду твоим пёсиком',
#   'Грустная девчонка с глазами как у собаки',
#   2018,
#   'electronic',
#   '3peGvpKhK1lBmvk8WdY8N5',
#   53],
#  ['Adam Beyer',
#   'Space Date',
#   'Space Date',
#   2018,
#   'electronic',
#   '1jghh4YdUcRLDEbda84AxM',
#   30],
#  ['Califato ¾',
#   'Arpexín',
#   "L'ambôccá",
#   2018,
#   'electronic',
#   '1lEUl5MKbOJ9dTw3E9fkCW',
#   16],
#  ['Forest Swords',
#   'Crow (DJ-Kicks) - Mixed',
#   'DJ-Kicks (Forest Swords) [DJ Mix]',
#   2018,
#   'electronic',
#   '4s5zfEwFuufmA9KLDHF8ft',
#   40],
#  ['Lookas',
#   'Alarm - WE ARE FURY Remix',
#   'Lucid (The Remixes)',
#   2018,
#   'electronic',
#   '4ZbQvhuML79GPnoxloXE0j',
#   36],
#  ['Krystal Klear',
#   'Neutron Dance',
#   'The Division',
#   2018,
#   'electronic',
#   '2dxiLe0Pq6pG058eYMbrn7',
#   40],
#  ['Novalima',
#   'Bandolero',
#   'Afro',
#   2018,
#   'electronic',
#   '3pZ7P4OtLKFluIWakhmvE1',
#   29],
#  ['Baauer', '3AM', '3AM', 2018, 'electronic', '1Xy3l3q7GuHQ2N1QEuRYTt', 48],
#  ['Lucky Luke',
#   'Make Ü Mine',
#   'Make Ü Mine',
#   2018,
#   'electronic',
#   '7DTci0p38WIDN96bd5LUZZ',
#   38],
#  ['Dirty Doering',
#   'If I Could I Would',
#   'Euch die Uhren uns die Zeit',
#   2018,
#   'electronic',
#   '1x20Z90kzwAdj5iyFxwW9w',
#   38],
#  ['Pional',
#   'Tempest',
#   'Miracle / Tempest',
#   2018,
#   'electronic',
#   '3NI5LmmAZ8khMBn2JBQeUO',
#   32],
#  ['Paul Kalkbrenner',
#   'Part Fourteen',
#   'Parts of Life',
#   2018,
#   'electronic',
#   '76Rjs9JHIRY6HdCQ8r87Jz',
#   35],
#  ['Sahalé',
#   'Magharibi - Satori Remix',
#   'Yam',
#   2018,
#   'electronic',
#   '3hVnNyWrnjfVLMBMVP5Bic',
#   38],
#  ['CLUBZ',
#   'Áfrika',
#   'Destellos',
#   2018,
#   'electronic',
#   '5cY6iwmzNfroYMCuLOlJio',
#   45],
#  ['Guy Gerber',
#   'What To Do - (Mixed)',
#   'Global Underground: Adapt #2 (Mixed)',
#   2018,
#   'electronic',
#   '3b8EAvwU10M3FLaTOTwV7R',
#   37],
#  ['DjRUM',
#   'Unblocked',
#   'Portrait with Firewood',
#   2018,
#   'electronic',
#   '7ijN9YMVkJ3QWte6p7JoVq',
#   38],
#  ['Thievery Corporation',
#   'La Force de Melodie',
#   'Treasures From The Temple',
#   2018,
#   'electronic',
#   '47BLkP6NITosyh2tcJ5mVV',
#   37],
#  ['Kermesse',
#   'Le Fleur',
#   'Kermesse',
#   2018,
#   'electronic',
#   '3a0bjBQ1AovuBcalR4GhYY',
#   36],
#  ['Rhye', 'Please', 'Blood', 2018, 'electronic', '4yXVtcNiaFUVDK8nno5ZWm', 37],
#  ['Rasi Z',
#   'Zamin',
#   'Buddha Bar XX',
#   2018,
#   'electronic',
#   '6qPudIy1L0Ud5B0RixPZgU',
#   39],
#  ['Shkoon',
#   'Napauken - Jpattersson Remix',
#   'Zehna',
#   2018,
#   'electronic',
#   '2vPP6FNAzYoo2pplHp7Vop',
#   40],
#  ['Jean-Michel Jarre',
#   'Arpegiateur',
#   'Planet Jarre (Deluxe-Version)',
#   2018,
#   'electronic',
#   '01BaOczvalXvzoTjp6xSnd',
#   31],
#  ['Jean-Michel Jarre',
#   'Coachella Opening',
#   'Planet Jarre (Deluxe-Version)',
#   2018,
#   'electronic',
#   '60IAA0HEs6i7OMf59jug3I',
#   31],
#  ['Against All Logic',
#   'This Old House Is All I Have',
#   '2012 - 2017',
#   2018,
#   'electronic',
#   '4uBNhssvTuBP3JzUEgfln6',
#   41],
#  ['Rhye', 'Softly', 'Blood', 2018, 'electronic', '1U2YcRtLZ4mdrvcO6qaTKR', 34],
#  ['Rival Consoles',
#   'Untravel',
#   'Persona',
#   2018,
#   'electronic',
#   '39tUHDzQ5nlGPtYaA71Y9v',
#   36],
#  ['Andrew Meller',
#   'Body & Soul - Radio Edit',
#   'Body & Soul',
#   2018,
#   'electronic',
#   '0wLjxFEYCnS6dHJ7SObwDU',
#   31],
#  ['CA7RIEL',
#   'Para la Forever',
#   'LIVRE',
#   2018,
#   'electronic',
#   '2A0AJfC9Pjfyp6WXUWVjQf',
#   34],
#  ['Joep Mencke',
#   'Trust The Wild',
#   "The Feathers' Eyes, Vol. 1",
#   2018,
#   'electronic',
#   '2TzddWEjBQjYuFgceeQhxi',
#   38],
#  ['RL Grime',
#   'I Wanna Know',
#   'NOVA',
#   2018,
#   'electronic',
#   '5NYiAtgAFWCwEpfSZOHFA7',
#   54],
#  ['Jean-Michel Jarre',
#   'THE OPENING (movement 8)',
#   'Equinoxe Infinity',
#   2018,
#   'electronic',
#   '24CyE6SLG5VS3MoEcRKbmY',
#   31],
#  ['Justice',
#   'Pleasure x Newjack x Civilization (WWW)',
#   'Woman Worldwide',
#   2018,
#   'electronic',
#   '4qjaG01IhHt3ZdO1FVakbs',
#   39],
#  ['Califato ¾',
#   'Ar-Xapâh',
#   "L'ambôccá",
#   2018,
#   'electronic',
#   '5tCQjt95xBglluuWQu80Ya',
#   14],
#  ['UMEK',
#   'Amnesiac',
#   'Amnesiac',
#   2018,
#   'electronic',
#   '6Jc2JwG3x88HT9UZAbLSJd',
#   35],
#  ['Peces Raros',
#   'Girando en Falso',
#   'Anestesia',
#   2018,
#   'electronic',
#   '6phjH1prCWCcKAYiRONHJx',
#   41],
#  ['Soft Blade',
#   'Zerkalo',
#   'Zerkalo',
#   2018,
#   'electronic',
#   '4BMJxzyJp82AknBSFGhTW7',
#   45],
#  ['Stavroz',
#   'It Was All a Ruse',
#   'Kasambila',
#   2018,
#   'electronic',
#   '0KWXCP6V9hXfyqbWN2wvZ8',
#   36],
#  ['Tebra', 'Suton', 'Suton', 2018, 'electronic', '6eq7V6zHwnHlRvjbWVA5nJ', 39],
#  ['Califato ¾',
#   'Hambre de Çangre',
#   "L'ambôccá",
#   2018,
#   'electronic',
#   '6cZOaNAMFt7aMuD0O0oqwD',
#   14],
#  ['Jon Hopkins',
#   'Emerald Rush',
#   'Singularity',
#   2018,
#   'electronic',
#   '5S3F5GL8LASIjPg2PMiU1Q',
#   39],
#  ['Poshlaya Molly',
#   'Типичная вечеринка с бассейном',
#   'Грустная девчонка с глазами как у собаки',
#   2018,
#   'electronic',
#   '1ndGHWAEXWz9jVr5bAgCrU',
#   51],
#  ['Paul Kalkbrenner',
#   'Part Twelve',
#   'Parts of Life',
#   2018,
#   'electronic',
#   '3EK6bvuN2elGa6lYmdmYf6',
#   34],
#  ['islandman',
#   'Khepre',
#   'Heimlich III',
#   2018,
#   'electronic',
#   '4oDj9KjjAHfKIlERxoUu1f',
#   37],
#  ['Jean-Michel Jarre',
#   'Rendez-Vous II, Pt. 4',
#   'Planet Jarre (Deluxe-Version)',
#   2018,
#   'electronic',
#   '6qcYZ3QONKpKsHEPHtVqRh',
#   29],
#  ['Gaullin',
#   'Op Opa',
#   'Op Opa',
#   2018,
#   'electronic',
#   '5ZDv6cSFtX1j0ZvULDCAGV',
#   42],
#  ['Pejzaż',
#   'Uważaj Jak Tańczysz',
#   'Ostatni Dzień Lata',
#   2018,
#   'electronic',
#   '23Nk2Wu1FRdVrRoklXZtCA',
#   39],
#  ['DJ Snake',
#   "Let's Get Ill",
#   "Let's Get Ill",
#   2018,
#   'electronic',
#   '3J5AcWRzmgbq4svZt91l3e',
#   40],
#  ['Maribou State',
#   'Slow Heat',
#   'Kingdoms In Colour',
#   2018,
#   'electronic',
#   '570ETApQMCYLqOojX4ISiN',
#   42],
#  ['Rapossa',
#   'Oriental Tales',
#   'Shanti',
#   2018,
#   'electronic',
#   '1ljBBK6uIhjuxmL7etHP39',
#   38],
#  ['ZOYA',
#   'In My Mind - Anagramma Remix',
#   'In My mind: The Remixes',
#   2018,
#   'electronic',
#   '6RVPKIzyWww58McfYwk0JV',
#   33],
#  ['Fatboy Slim',
#   'Praise You (Purple Disco Machine Extended Remix)',
#   'Praise You (Purple Disco Machine Remix)',
#   2018,
#   'electronic',
#   '0ZJgePC21TJkw5p2jUA8iC',
#   33],
#  ['Satori', 'Fauna', 'Yam', 2018, 'electronic', '349HUfae4p6KJ5aFAUfP1L', 35],
#  ['Rhye', 'Waste', 'Blood', 2018, 'electronic', '4bSr1hSKGJzglijKfIrcvo', 35],
#  ['Valentino Khan',
#   'Lick It',
#   'Lick It',
#   2018,
#   'electronic',
#   '2AUHVjR5lhg6GcztbGvRkc',
#   40],
#  ['Leon Vynehall',
#   'Envelopes (Chapter VI) - Edit',
#   'Envelopes',
#   2018,
#   'electronic',
#   '3JDsYB8UxGbMQNnNlAeDL0',
#   38],
#  ['Rhye',
#   'Count To Five',
#   'Blood',
#   2018,
#   'electronic',
#   '6Rp8ptCpxsdmC3O4LSsJZg',
#   35],
#  ['Kölsch', 'HAL', 'HAL', 2018, 'electronic', '0ZY9kPt23t9OVMLyybvKCj', 36],
#  ['Matanza',
#   'Heidi',
#   'Matanza',
#   2018,
#   'electronic',
#   '5ZPCVH9Jy65G0jw4xjkuO0',
#   33],
#  ['Kermesse',
#   'Camomille',
#   'Dub kantine EP',
#   2018,
#   'electronic',
#   '4AyHuAzcc1wlVV3kuLb5uM',
#   36],
#  ['Fatboy Slim',
#   'Gangster Trippin - Sultan + Shepard Remix',
#   'Gangster Trippin (Sultan + Shepard Remix)',
#   2018,
#   'electronic',
#   '19VVmenPRBEdWwg0Vp2lKh',
#   35],
#  ['Shkoon', 'Lala', 'Lala', 2018, 'electronic', '5FJiSLoCEAV9fkX4oZd2ou', 41],
#  ['Morcheeba',
#   'Blaze Away',
#   'Blaze Away',
#   2018,
#   'electronic',
#   '4QRdgb658a1ILXogewjAi8',
#   33],
#  ['Spartaque',
#   'Who You Are - Edit',
#   'In the Shade (Edits)',
#   2018,
#   'electronic',
#   '4CQTHh9mXYzIXTWKKApetQ',
#   32],
#  ['Dian Solo',
#   'Cocaine - Radio Edit',
#   'Cocaine',
#   2018,
#   'electronic',
#   '5rvue7qdTYOYpwOWRare9i',
#   36],
#  ['Jean-Michel Jarre',
#   'FLYING TOTEMS (movement 2)',
#   'Equinoxe Infinity',
#   2018,
#   'electronic',
#   '05M6zX62Q2k2u7W6NuxLTR',
#   28],
#  ['Paul Kalkbrenner',
#   'Part Eight',
#   'Part Eight',
#   2018,
#   'electronic',
#   '2yAOaUhMCX7irO3N1ygHs4',
#   32],
#  ['Dean Blunt',
#   'SOMALIA PARK',
#   'Soul On Fire',
#   2018,
#   'electronic',
#   '1dAD3L0H2pOGkpYFRup5Ab',
#   46],
#  ['Apparat',
#   'Goodbye - Theme from Dark, a Netflix Original Series',
#   'Goodbye (Theme from Dark, a Netflix Original Series)',
#   2018,
#   'electronic',
#   '6qMcBfQ3Dy3Cn6q27tcQDR',
#   36],
#  ['Moby',
#   'Mere Anarchy - Edit',
#   'Mere Anarchy',
#   2018,
#   'electronic',
#   '5tQhscGYHfrdCPKB73hYAI',
#   23],
#  ['Maribou State',
#   'Turnmills - Edit',
#   'Kingdoms In Colour',
#   2018,
#   'electronic',
#   '3HzSuE22PGsbPstPLv44M7',
#   39],
#  ['George FitzGerald',
#   'Burns',
#   'All That Must Be',
#   2018,
#   'electronic',
#   '2DeV4SryfbbEM1YgedzKP4',
#   39],
#  ['Milk & Sugar',
#   'Let the Sun Shine - Milk & Sugar Edit',
#   'Let the Sun Shine (Milk & Sugar Edit) [Milk & Sugar Remix]',
#   2018,
#   'electronic',
#   '4XxcnzCAR91UI5LknaHURL',
#   29],
#  ['Ash',
#   'Keep Me',
#   'Keep Me',
#   2018,
#   'electronic',
#   '5McDChwXMGO5SvOrACiBHO',
#   40],
#  ['Monetochka',
#   'Ночной ларёк',
#   'Раскраски для взрослых',
#   2018,
#   'electronic',
#   '3nTUFj1o2hkgaWQ0AWYfQc',
#   45],
#  ['Maribou State',
#   'Turnmills',
#   'Kingdoms In Colour',
#   2018,
#   'electronic',
#   '5m4o1robU6yTvFDXXSrH0F',
#   40],
#  ['Anchorsong',
#   'Ancestors',
#   'Cohesion',
#   2018,
#   'electronic',
#   '5UoN1ldp7kLaPzCSpo3ufA',
#   34],
#  ['Jean-Michel Jarre',
#   "ROBOTS DON'T CRY (movement 3)",
#   'Equinoxe Infinity',
#   2018,
#   'electronic',
#   '7vQqaXVfyEk7AJvV6PUpss',
#   29],
#  ['Be Svendsen',
#   'Day 3',
#   'Between a Smile and a Tear',
#   2018,
#   'electronic',
#   '5fSFt5Z9vlUG09LaHtQX6J',
#   36],
#  ['Butch',
#   'Countach - Original',
#   'Countach',
#   2018,
#   'electronic',
#   '4yjoFroiLO7KpM2CDUH2ie',
#   29],
#  ['Bob Moses',
#   'Heaven Only Knows',
#   'Battle Lines',
#   2018,
#   'electronic',
#   '4pjP1IGE3JC0jDvgPkHHcg',
#   37],
#  ['Jeremy Vancaulart',
#   'Hurt',
#   'Hurt',
#   2018,
#   'electronic',
#   '13ZVANTwv0ANny7vTMGcji',
#   34],
#  ['Paul Kalkbrenner',
#   'Part Eight',
#   'Parts of Life',
#   2018,
#   'electronic',
#   '5SYF5CsnX8cVKVTzdemUgD',
#   30],
#  ['LOUTA',
#   'PUEDE SER',
#   'ENCHASTRE',
#   2018,
#   'electronic',
#   '71bO0OsW7odKFhbjrHwM8C',
#   38],
#  ['Lucky Luke',
#   'Keke',
#   'Keke',
#   2018,
#   'electronic',
#   '6JIy6CxXoxH2nt3hZozxql',
#   36],
#  ['islandman',
#   'Anadolu',
#   'VAUS 2 - Random Colletive Records',
#   2018,
#   'electronic',
#   '7ycECdNw14nleTOSS8nEaG',
#   34],
#  ['Flosstradamus',
#   '2 MUCH (feat. 24hrs)',
#   '2 MUCH (feat. 24hrs)',
#   2018,
#   'electronic',
#   '5YRmvwA6P4fABxRhc61iH9',
#   42],
#  ['Acid Pauli',
#   'Jorge - Satori Remix',
#   'Bld Remixes B',
#   2018,
#   'electronic',
#   '769LjA468VL4j2g4WI48Oe',
#   34],
#  ['Charlotte Adigéry',
#   'Paténipat',
#   'Paténipat',
#   2018,
#   'electronic',
#   '0STU4tz5QWwA46G8QkvtK1',
#   35],
#  ['Martin Jensen',
#   "Somebody I'm Not - Cahill Edit",
#   "Somebody I'm Not",
#   2018,
#   'electronic',
#   '29kQS8jVf08MEp6vFCF8Ot',
#   30],
#  ['Peter Cat Recording Co.',
#   'Love Demons',
#   'Portrait of a Time: 2010-2016',
#   2018,
#   'electronic',
#   '3wgx6kB0t5yTPcB7UP3p9b',
#   37],
#  ['Justice',
#   'Genesis x Phantom (WWW)',
#   'Woman Worldwide',
#   2018,
#   'electronic',
#   '7GTZa1773faSYybRdGDIjk',
#   37],
#  ['CLUBZ',
#   'Templos',
#   'Destellos',
#   2018,
#   'electronic',
#   '5BRBuj8WoTqSqCvIfEkzYx',
#   39],
#  ['Kerala Dust',
#   'Maria',
#   'Maria',
#   2018,
#   'electronic',
#   '3e8hBpyRJ7zYm35JUjTCwJ',
#   34],
#  ['Rival Consoles',
#   'Fragment',
#   'Persona',
#   2018,
#   'electronic',
#   '4G37OYV8HDnX01xdSyG2Ma',
#   35],
#  ['Zuma Dionys',
#   'As Time Goes By',
#   'Yuddhapot',
#   2018,
#   'electronic',
#   '4e9UIKY0dESrEdVGlxeVRW',
#   36],
#  ['WhoMadeWho',
#   'Dynasty',
#   'Through the Walls',
#   2018,
#   'electronic',
#   '1UglHGkDf43W58XZKdnqbE',
#   32],
#  ['George FitzGerald',
#   'Roll Back',
#   'All That Must Be',
#   2018,
#   'electronic',
#   '0smkE9zt2Bg7fFk0HlzR4C',
#   37],
#  ['Rodrigo Gallardo',
#   'El Abuelo - Dandara Remix',
#   'El Abuelo',
#   2018,
#   'electronic',
#   '49NKccHKnVnLSDa4J4yNTn',
#   29],
#  ['Paul Kalkbrenner',
#   'Part Three',
#   'Parts of Life',
#   2018,
#   'electronic',
#   '4u6bp7tS5NnJOj16FNAsNi',
#   31],
#  ['islandman',
#   'Rest In Space',
#   'Rest in Space',
#   2018,
#   'electronic',
#   '1VQnRQwgoO2HldXOAsIf2v',
#   33],
#  ['Maribou State',
#   'Part Time Glory',
#   'Kingdoms In Colour',
#   2018,
#   'electronic',
#   '5O8jA5esx67O3FoqKwBjQV',
#   38],
#  ['Ekali',
#   'Stay Hollow (with mossy.)',
#   'Crystal Eyes',
#   2018,
#   'electronic',
#   '1u3SkEgGroT2Kcfnd4v4ON',
#   41],
#  ['Lucky Luke',
#   'Never Stop',
#   'Never Stop',
#   2018,
#   'electronic',
#   '4Qah8zVDlmDsnmKuY9mC0Q',
#   37],
#  ['Kora (CA)',
#   'Kanjira',
#   'Nous / Kanjira',
#   2018,
#   'electronic',
#   '3ajiQwDHMWEVxZKXWPZtNg',
#   35],
#  ['San Holo',
#   'lift me from the ground',
#   'album1',
#   2018,
#   'electronic',
#   '7kZVirTc3V6d4YWtu6RaAu',
#   48],
#  ['Pensees',
#   'Your Lips - Original Mix',
#   'Your Lips',
#   2018,
#   'electronic',
#   '3ByKecIVNswbnmOMCTXPt6',
#   35],
#  ['Moby',
#   'This Wild Darkness',
#   'Everything Was Beautiful, and Nothing Hurt',
#   2018,
#   'electronic',
#   '2MBr8LzNJ4r0C5mIKgFSUw',
#   25],
#  ['DjRUM',
#   'Blood in My Mouth',
#   'Portrait with Firewood',
#   2018,
#   'electronic',
#   '2j99yeFnWhjKquM4ACAD74',
#   33],
#  ['DVBBS', 'IDWK', 'IDWK', 2018, 'electronic', '4ABdTWafMCXfATpILRuZFW', 43],
#  ['Mark Alow',
#   'Quasar',
#   'Nebula EP',
#   2018,
#   'electronic',
#   '2GfgaTAmEmtQTzpCbHOIs1',
#   33],
#  ['Mick Gordon',
#   'Reich Between the Eyes',
#   'Wolfenstein II: The New Colossus (Original Game Soundtrack)',
#   2018,
#   'electronic',
#   '2T15NZyQUjmH04GqM0ahyy',
#   38],
#  ['Sísý Ey',
#   'Restless - Crazy P Extended Vocal Mix',
#   'Restless',
#   2018,
#   'electronic',
#   '6q6gzEJCKWFEw0KirXtirz',
#   32],
#  ['Alef',
#   'Luna',
#   'Sol y Luna',
#   2018,
#   'electronic',
#   '5bUayZvlP6Qw2x8TBrW8XX',
#   34],
#  ['Rodrigo Gallardo',
#   'Minero',
#   'Minero',
#   2018,
#   'electronic',
#   '0ZEQcLlNxQI1McXdTX3QQZ',
#   32],
#  ['George FitzGerald',
#   'Roll Back - Single Mix',
#   'Roll Back',
#   2018,
#   'electronic',
#   '7ko64FZgc63TnZuYhusU21',
#   37],
#  ['Ross from Friends',
#   'Family Portrait',
#   'Family Portrait',
#   2018,
#   'electronic',
#   '4SqFKz56kpmQGfMLEAzEJL',
#   37],
#  ['Hraach',
#   'Silver Cord',
#   'Silver Cord',
#   2018,
#   'electronic',
#   '0HbSrhvUNoesTOyNUdqyUN',
#   34],
#  ['Babasonicos',
#   'Cretino',
#   'Discutible',
#   2018,
#   'electronic',
#   '7cZXR7MmUEtIE5FqNV9Cl2',
#   40],
#  ['WATEVA',
#   'Ber Zer Ker',
#   'Ber Zer Ker',
#   2018,
#   'electronic',
#   '3dAvoxoiRsAGa87VPMnbbl',
#   35],
#  ['Matanza',
#   'Canto al Fuego',
#   'Matanza',
#   2018,
#   'electronic',
#   '3R9l60BDCH4pq8iaR44i0O',
#   32],
#  ['Jerome Robins',
#   'Finally - Mart Remix',
#   'Toronto Pride 2018',
#   2018,
#   'electronic',
#   '5x22ZfdSlIVKmGAU2cNAHH',
#   24],
#  ['DjRUM',
#   'Creature, Pt. 1',
#   'Portrait with Firewood',
#   2018,
#   'electronic',
#   '38KFHXttkrIpnUd0tTvkZj',
#   34],
#  ['Peter Cat Recording Co.',
#   'Copulations',
#   'Portrait of a Time: 2010-2016',
#   2018,
#   'electronic',
#   '0caFvsrnGwE9dIq18zAGtt',
#   35],
#  ['Nils Frahm',
#   'A Place',
#   'All Melody',
#   2018,
#   'electronic',
#   '01CPfUmFuqqqlOq4X9Bl75',
#   33],
#  ['Snavs',
#   'Turn Left',
#   'Turn Left',
#   2018,
#   'electronic',
#   '5TG8HeWIIvveI3rRu0yJui',
#   36],
#  ['Paul Kalkbrenner',
#   'Part Thirteen',
#   'Parts of Life',
#   2018,
#   'electronic',
#   '71ZkE3EqcE02Eg9oLNRh83',
#   30],
#  ['Paul Kalkbrenner',
#   'Part Six',
#   'Parts of Life',
#   2018,
#   'electronic',
#   '73SymHomgyA6TKjlqOYfSG',
#   30],
#  ['Nicolas Godin',
#   'Alger la blanche',
#   'Au service de la France',
#   2018,
#   'electronic',
#   '2cu3X3pbKbHdmRzCDkKTsO',
#   36],
#  ['Andrew Meller',
#   'Born Slippy - Reincarnation Mix',
#   'Born Slippy',
#   2018,
#   'electronic',
#   '7aAv7FzsUEw7Zg3R7clpgT',
#   29],
#  ['Mr Raoul K',
#   'Tamale',
#   'African Paradigm',
#   2018,
#   'electronic',
#   '0pu8eMJEVLFmScMKg3Lhda',
#   32],
#  ['Justice',
#   'Love S.O.S. (WWW)',
#   'Woman Worldwide',
#   2018,
#   'electronic',
#   '0oBwbnefM7yniHJPjNrIVK',
#   37],
#  ['Black Tiger Sex Machine',
#   'Lions - Doctor P Remix',
#   'Lions (Doctor P Remix)',
#   2018,
#   'electronic',
#   '6exH1RP0wkEQgfHJ3rd2mP',
#   41],
#  ['KC Lights',
#   'Change the World (feat. Nicole Dash Jones) - Strings In Motion Mix',
#   'Change The World (Strings) (feat. Nicole Dash Jones)',
#   2018,
#   'electronic',
#   '1C3arE9PgTbFPLp5n1c8PE',
#   34],
#  ['Kiasmos',
#   'Zebra',
#   'Erased Tapes 1+1=X',
#   2018,
#   'electronic',
#   '2fQv1XI0BMqtJv35UYEgWf',
#   30],
#  ['Talisto',
#   'Te Llamé',
#   'Te Llamé',
#   2018,
#   'electronic',
#   '4x76yO3NmhiQSnHcBjtrml',
#   29],
#  ['Xinobi',
#   'Dance to Hits',
#   'Dance to Hits',
#   2018,
#   'electronic',
#   '3teeO1JcrNHPPChdF7KDtL',
#   32],
#  ['AL-90',
#   'Black Sapphire',
#   'Murmansk-60',
#   2018,
#   'electronic',
#   '2pa3KuBNIgdo2zjjXuji4j',
#   40],
#  ['Anthony Keyrouz',
#   'Mohicans - Radio Edit',
#   'Mohicans',
#   2018,
#   'electronic',
#   '29spMtlFV1U1UfJ4LXNkTY',
#   30],
#  ['Moderat',
#   'Invaluable Waste from the Outlying Districts, Pt. 02',
#   'A Thought of Ecstasy',
#   2018,
#   'electronic',
#   '017D51oVbvImE3kUFhXc6B',
#   30],
#  ['Shanti People',
#   'Mahishasura Mardini - Droplex Remix',
#   'Mahishasura Mardini (Droplex Remix)',
#   2018,
#   'electronic',
#   '3acayW3swCZVU3Uy8c3VkK',
#   43],
#  ['Felix Cartal',
#   'Get What You Give',
#   'Next Season',
#   2018,
#   'electronic',
#   '7Kur4cXMHU8KE1AHKQD7w7',
#   38],
#  ['Bomba Estéreo',
#   'Inside Me - Live',
#   'Live in Dublin',
#   2018,
#   'electronic',
#   '5GlwJrLgWTGxUCeVmfqCYl',
#   22],
#  ['Monetochka',
#   'Super KICA 8bit',
#   'Super KICA 8bit',
#   2018,
#   'electronic',
#   '327rdAySCj5xFmCx1QUUmd',
#   45],
#  ['Soft Blade',
#   'Untitled28',
#   'Zerkalo',
#   2018,
#   'electronic',
#   '0iYH1BFtldyHdwYyYPTC7o',
#   40],
#  ['Francis Lai',
#   'Somewhere in the Night - From Madly',
#   'Madly (Bande originale du film avec Alain Delon)',
#   2018,
#   'electronic',
#   '4qHRgbOZJt487Gm5N4vljJ',
#   25],
#  ['Marie Davidson',
#   'Work It',
#   'Working Class Woman',
#   2018,
#   'electronic',
#   '5QnzAZ2W3Ap3gSiO2vsGQG',
#   31],
#  ['Dwin',
#   'Cityyyyyy Lifeee',
#   'Cityyyyyy Lifeee',
#   2018,
#   'electronic',
#   '0eXpxSvHGCLQJguntYU1Km',
#   42],
#  ['What So Not',
#   'Goh',
#   'Not All the Beautiful Things',
#   2018,
#   'electronic',
#   '1EhlpDCrgmBslyQ6jwgxSH',
#   30],
#  ['Be Svendsen',
#   'Le Piroguier - Be Svendsen Remix',
#   'Between a Smile and a Tear',
#   2018,
#   'electronic',
#   '2qVc3mVAW2MCsVzTC5rKaq',
#   33],
#  ['KETTAMA',
#   'B O D Y',
#   'Bucklyn Bridge EP',
#   2018,
#   'electronic',
#   '0Uwq5TKfVfanVZzoVCz620',
#   44],
#  ['Jean-Michel Jarre',
#   'MACHINES ARE LEARNING (movement 7)',
#   'Equinoxe Infinity',
#   2018,
#   'electronic',
#   '0kgB70BEoFU5CIddZLU6qD',
#   26],
#  ['Jerome Robins',
#   "Groovejet (If This Ain't Love) - Earth n Days Remix",
#   "Groovejet (If This Ain't Love) (Earth n Days Remix)",
#   2018,
#   'electronic',
#   '1PvYLQ12iG4vmkjPFdQemw',
#   28],
#  ['UMEK',
#   'Collision Wall',
#   'Collision Wall',
#   2018,
#   'electronic',
#   '0dCOxB07cxEtZPfAZmAytj',
#   27],
#  ['BLOOM',
#   'Tentacion',
#   'El Mundo EP, Pt. 2',
#   2018,
#   'electronic',
#   '59rWkhcPYG89x8GUUzJ9gF',
#   33],
#  ['Ephixa',
#   'Dreamstate',
#   'Dreamstate',
#   2018,
#   'electronic',
#   '4WOYAnPBe0qqlgcVAPLCd8',
#   42],
#  ['Kölsch',
#   'Left Eye Left',
#   'Left Eye Left',
#   2018,
#   'electronic',
#   '2m2Si8RtoOGPfbIjDx9Ug7',
#   35],
#  ['Yan Tregger',
#   'Sunny Wing',
#   'Catchy',
#   2018,
#   'electronic',
#   '4vg3KGQs568DXacMJUbAaT',
#   35],
#  ['Justice',
#   'Safe and Sound (WWW)',
#   'Woman Worldwide',
#   2018,
#   'electronic',
#   '2OPmeyf31LlcIpYcJ4aegt',
#   36],
#  ['Black Tiger Sex Machine',
#   'Zombie feat. Panther',
#   'New Worlds',
#   2018,
#   'electronic',
#   '6Ytdv9pEdBWdVfo1my1Ud8',
#   36],
#  ['Shkoon',
#   'Napauken Feat. Fruiterama',
#   'Zehna',
#   2018,
#   'electronic',
#   '4CJtnJh0NhpDyBpCvh0Mff',
#   35],
#  ['Jon Hopkins',
#   'Singularity',
#   'Singularity',
#   2018,
#   'electronic',
#   '4oZ2Xkline6CvRDebjbi8Q',
#   34],
#  ['Fatboy Slim',
#   'Right Here Right Now (CamelPhat Remix)',
#   'Right Here Right Now (CamelPhat Remix)',
#   2018,
#   'electronic',
#   '3SzPA7bBOiaF4mvcujTGvy',
#   28],
#  ['Justice',
#   'Heavy Metal x DVNO (WWW)',
#   'Woman Worldwide',
#   2018,
#   'electronic',
#   '1qXBcPpscF2eynmVkITml7',
#   36],
#  ['Novalima',
#   'Herejia',
#   "Ch'usay",
#   2018,
#   'electronic',
#   '5nQTVn417aepqNo6BF9fMN',
#   24],
#  ['Andre Rizo',
#   'Kiss me (feat. Lola Jane) - original mix',
#   'Kiss me (feat. Lola Jane)',
#   2018,
#   'electronic',
#   '1cSy9X7m5QpWxJQMMNvseO',
#   29],
#  ['Solomun',
#   'Customer Is King',
#   'Customer Is King EP',
#   2018,
#   'electronic',
#   '6wHxJC4smaOq7eJrjxN462',
#   32],
#  ['Dian Solo',
#   'Bad - Radio Edit',
#   'Bad',
#   2018,
#   'electronic',
#   '0cc3tUvBZWoFhvaT79Iq5L',
#   26],
#  ['Justice',
#   'Canon x Love S.O.S. (WWW)',
#   'Woman Worldwide',
#   2018,
#   'electronic',
#   '50fkJxrv0ZLTt9EHZGBOP7',
#   36],
#  ['Mark Reeve',
#   'Far Away',
#   'Far Away',
#   2018,
#   'electronic',
#   '2Ek7dkebbBIlwvkIz08UvC',
#   30],
#  ['ARTBAT',
#   'Papillon',
#   'Papillon',
#   2018,
#   'electronic',
#   '1vpOY0slxNwm6EO7ykjsfZ',
#   34],
#  ['Bob Moses',
#   'Back Down',
#   'Battle Lines',
#   2018,
#   'electronic',
#   '0f996DWK1s2jQXIVZihKKZ',
#   39],
#  ['Traf',
#   'John Wolfgang',
#   'John Wolfgang',
#   2018,
#   'electronic',
#   '70rwRFd6c641SHt3HUkk2L',
#   36],
#  ['Nils Frahm',
#   'Sunson',
#   'All Melody',
#   2018,
#   'electronic',
#   '6Irt9GvjTLQQDDgb3vqU0y',
#   33],
#  ['Ross from Friends',
#   'The Knife',
#   'Family Portrait',
#   2018,
#   'electronic',
#   '7f4nJBRW8hPkeAkm30YNRN',
#   36],
#  ['Leon Vynehall',
#   'Movements (Chapter III) - Edit',
#   'Movements',
#   2018,
#   'electronic',
#   '16HsMUMtMSmkpR2ybn8cT3',
#   34],
#  ['Monetochka',
#   '90',
#   'Раскраски для взрослых',
#   2018,
#   'electronic',
#   '60l4oXaV6WyBAj9LrC3pBO',
#   41],
#  ['Poshlaya Molly',
#   'ЛОЛ',
#   'ОЧЕНЬ СТРАШНАЯ МОЛЛИ 3, Ч. 1',
#   2018,
#   'electronic',
#   '5NTsL6nb0hvesPzfVgt5vU',
#   46],
#  ['Rodge',
#   'Beirut',
#   'Beirut',
#   2018,
#   'electronic',
#   '0XnojCdBGCLuoeOTZUfaM7',
#   32],
#  ['Rhye', 'Sinful', 'Blood', 2018, 'electronic', '3wbDA6hrNhmY3KhRbWgVDx', 31],
#  ['Dr. Ozi',
#   'Pitchforks & Fire',
#   'Pitchforks & Fire / Formula',
#   2018,
#   'electronic',
#   '6TIJQMR0Rnzq7joAqE2eqe',
#   32],
#  ['Autoerotique',
#   "Count On You - ATFC's C-thru Remix",
#   "Count On You (ATFC's C-thru Remix)",
#   2018,
#   'electronic',
#   '7GL2SOvJXs8QVLX0cUADeq',
#   27],
#  ['Dean Blunt',
#   'CHANCER',
#   'Soul On Fire',
#   2018,
#   'electronic',
#   '1eBcb3Vclf5bE3L0F0GUFr',
#   42],
#  ['Leon Vynehall',
#   'From The Sea/It Looms (Chapters I & II)',
#   'Nothing Is Still',
#   2018,
#   'electronic',
#   '0lDKZO6dS927plsK7SGmh4',
#   35],
#  ['Rival Consoles',
#   'Be Kind',
#   'Persona',
#   2018,
#   'electronic',
#   '3rkesmzecZXrKZ7HA68OKZ',
#   32],
#  ['Holed Coin',
#   'Uiaju - Rodrigo Gallardo Remix',
#   'Clouds EP',
#   2018,
#   'electronic',
#   '4sVl5s3N69tlt3mSuN8nrD',
#   31],
#  ['BLOOM',
#   'Loros y Hojas',
#   'El Mundo EP, Pt. 2',
#   2018,
#   'electronic',
#   '55VvpI63ElUtmCXjKrnJrZ',
#   29],
#  ['Monetochka',
#   'Запорожец',
#   'Раскраски для взрослых',
#   2018,
#   'electronic',
#   '70vpUtZNiBoQoMXXK1NiZ1',
#   43],
#  ['Mark Alow',
#   'Nebula',
#   'Nebula EP',
#   2018,
#   'electronic',
#   '3WQUvDF2NrE56DNCDkfHpr',
#   29],
#  ['False Noise',
#   'Shiver',
#   'Shiver',
#   2018,
#   'electronic',
#   '5HbKNT3keqFwtFNqhzMV9J',
#   32],
#  ['Nils Frahm',
#   'All Melody',
#   'All Melody',
#   2018,
#   'electronic',
#   '3OaCGuWEXcT1ygvV1IwQ0H',
#   32],
#  ['Jean-Michel Jarre',
#   'THE WATCHERS (movement 1)',
#   'Equinoxe Infinity',
#   2018,
#   'electronic',
#   '048UDvWoL3ijmqFiGZni6j',
#   26],
#  ['SLUMBERJACK',
#   'Solid',
#   'Solid',
#   2018,
#   'electronic',
#   '0oS4QNvqkCnD50vWTaKnm0',
#   32],
#  ['Elfenberg',
#   'Bazaar',
#   'Lotus',
#   2018,
#   'electronic',
#   '6bUbYsviBSPJXRZLClY54A',
#   33],
#  ['Black Math',
#   'Point Blank',
#   'Point Blank',
#   2018,
#   'electronic',
#   '6jK5D4hCRGg7OmWeOrZlQl',
#   37],
#  ['Flosstradamus',
#   'MVP (feat. Smokepurpp) - NGHTMRE Remix',
#   'MVP (feat. Smokepurpp) [NGHTMRE Remix]',
#   2018,
#   'electronic',
#   '2zeMc8pgpR1HRgMVCDUPYq',
#   29],
#  ['Manuel Riva',
#   'Miami - Radio Edit',
#   'Miami',
#   2018,
#   'electronic',
#   '20WMh5sH8yyHSnFDyPImcn',
#   30],
#  ['Justice',
#   'D.A.N.C.E. x Fire x Safe and Sound (WWW)',
#   'Woman Worldwide',
#   2018,
#   'electronic',
#   '2BbUJuG2a06CQntBvL1B2T',
#   34],
#  ['Hosini',
#   'And U - Mixed',
#   'Café del Mar Terrace Mix 8',
#   2018,
#   'electronic',
#   '2ldKqHkR5JbzEJXzNKaI1s',
#   30],
#  ['Monetochka',
#   'Твоё имя',
#   'Раскраски для взрослых',
#   2018,
#   'electronic',
#   '060vEek3IcP3se8apjxo32',
#   42],
#  ['Be Svendsen',
#   'Drop the Gun',
#   'Between a Smile and a Tear',
#   2018,
#   'electronic',
#   '4pl6jSbip4nb10NX2xAEnx',
#   31],
#  ['Butch',
#   'Countach - Kölsch Remix',
#   'Countach',
#   2018,
#   'electronic',
#   '2mwptYSUenZkc1EL20HC30',
#   33],
#  ['Vigiland',
#   'Never Going Home',
#   'V',
#   2018,
#   'electronic',
#   '3JMjmQ4xsvEr7cP1mDS8sq',
#   38],
#  ['Dean Blunt',
#   'cloudhopper',
#   'Muggy Vol.1',
#   2018,
#   'electronic',
#   '6jXwZBa5QU59gfxRXXpxna',
#   40],
#  ['Peces Raros',
#   'Nenúfares Perfectos',
#   'Anestesia',
#   2018,
#   'electronic',
#   '4gR8cHoZppxSTPn2ESGy3W',
#   35],
#  ['Jeremy Vancaulart',
#   'Hurt (Mixed)',
#   'ASOT 896 - A State Of Trance Episode 896 (A State Of Trance Year Mix 2018)',
#   2018,
#   'electronic',
#   '3VVKtzKM8XKhg27Jdw90pw',
#   30],
#  ['Valeron',
#   'Anlar',
#   'Anlar',
#   2018,
#   'electronic',
#   '30rDKZPuQxu8US9AVEWkE7',
#   39],
#  ['Andrew Meller',
#   'Born Slippy - Reincarnation Edit',
#   'Born Slippy',
#   2018,
#   'electronic',
#   '1hZCT7LgxK5KVyLUtJMDJW',
#   27],
#  ['Ash',
#   'Can I Exist',
#   'Can I Exist',
#   2018,
#   'electronic',
#   '464eGYAzBwZvFOsHZz6QWB',
#   35],
#  ['Rapossa',
#   'Shanti - Goldcap Remix',
#   'Shanti',
#   2018,
#   'electronic',
#   '2kQmAiPgeF0Nhlzt0U0MNU',
#   32],
#  ['Thom Yorke',
#   'Has Ended',
#   'Suspiria (Music for the Luca Guadagnino Film)',
#   2018,
#   'electronic',
#   '3nxbZvK0xjhnuBVtwmF3AK',
#   33],
#  ['Dotorado Pro',
#   'Sweet Afrika',
#   'Sweet Afrika',
#   2018,
#   'electronic',
#   '6x2cq684GrGhcMC2Xhj8Bp',
#   30],
#  ['Fabian Mazur',
#   'The Groove',
#   'The Groove',
#   2018,
#   'electronic',
#   '6cpGgmkHnF4GbilK2Vi4zW',
#   34],
#  ['Jean-Michel Jarre',
#   'Oxygene, Pt. 20',
#   'Planet Jarre (Deluxe-Version)',
#   2018,
#   'electronic',
#   '77OxKQa9FnIgMtgaIBb4if',
#   24],
#  ['Pensees',
#   'Alps - Original Mix',
#   'Completion',
#   2018,
#   'electronic',
#   '3qGRA5aWRTR06gi6mX0p7m',
#   33],
#  ['Habstrakt',
#   'About You',
#   'About You',
#   2018,
#   'electronic',
#   '3pxSiLCw1zNGwxTFRDg99Q',
#   21],
#  ['Shakarchi & Stranéus',
#   'Marcy Son What',
#   'Steal Chickens From Men And the Future From God',
#   2018,
#   'electronic',
#   '7A8Vs7W4K8GAxVQ6kakQRm',
#   33],
#  ['AL-90',
#   'Spurv Edit',
#   'Murmansk-60',
#   2018,
#   'electronic',
#   '5WDbPfIPIt9xasV7yjouFR',
#   36],
#  ['Digitalism',
#   'Glow',
#   'Glow',
#   2018,
#   'electronic',
#   '1Z2UlDPtTr5SDMuXzfayHb',
#   28],
#  ['Jean-Michel Jarre',
#   'Chronology, Pt. 4',
#   'Planet Jarre (Deluxe-Version)',
#   2018,
#   'electronic',
#   '6qgb0waKbiET6BJRMCGBWD',
#   22],
#  ['Paul Kalkbrenner',
#   'Part Two',
#   'Parts of Life',
#   2018,
#   'electronic',
#   '37VyMOZbx0uxo6kPtaPCQZ',
#   29],
#  ['Consoul Trainin',
#   '3 Daqat - Consoul Trainin vs. DuoViolins',
#   '3 Daqat (Consoul Trainin vs. DuoViolins)',
#   2018,
#   'electronic',
#   '045IY1XJjyUVwWrkqnsUpt',
#   29],
#  ['Alison Wonderland',
#   'Good Enough',
#   'Awake',
#   2018,
#   'electronic',
#   '1imPiGCRV9jQKShxESv3Tt',
#   29],
#  ['LOUTA',
#   'PALMERAS',
#   'ENCHASTRE',
#   2018,
#   'electronic',
#   '4dBZ6m6HnEGaBSnTfhKAhH',
#   33],
#  ['Jon Hopkins',
#   'Everything Connected',
#   'Singularity',
#   2018,
#   'electronic',
#   '3oWBMOzkjjkCmV6abncBUd',
#   32],
#  ['Valeron',
#   'Delos',
#   'Aigaio',
#   2018,
#   'electronic',
#   '1UdFBxdv0reB7EMOQqjsq0',
#   30],
#  ['Excision',
#   'Gold (Stupid Love)',
#   'Apex',
#   2018,
#   'electronic',
#   '7nEE5RihPZU6L5LZqDeEZD',
#   36],
#  ['Sevdaliza',
#   'Soul Syncable',
#   'The Calling',
#   2018,
#   'electronic',
#   '1nqPWkUco1HZNp4BrRK8Za',
#   32],
#  ['Zuma Dionys',
#   'Yuddhapot',
#   'Yuddhapot',
#   2018,
#   'electronic',
#   '0RVXmahRFNgaXtfg6umPde',
#   32],
#  ['Little Dragon',
#   'Lover Chanting',
#   'Lover Chanting EP',
#   2018,
#   'electronic',
#   '5w4MaPqhmDxhk7B2jygb16',
#   36],
#  ['Jeremy Olander',
#   'Zanzibar - Sthlm Radio Edit',
#   'Zanzibar',
#   2018,
#   'electronic',
#   '0I8YEyOTzu8PrmNEa5OPXl',
#   33],
#  ['Miss Monique',
#   'Tran',
#   'Tran',
#   2018,
#   'electronic',
#   '6N0dje7NbODzjsIbPnfXm6',
#   28],
#  ['Dengue Dengue Dengue',
#   'Pua',
#   'Semillero',
#   2018,
#   'electronic',
#   '4b3bYGxsCzLnPwQ5CyRlQX',
#   27],
#  ['Jody Wisternoff',
#   'For All Time - Extended Mix',
#   'For All Time',
#   2018,
#   'electronic',
#   '4W6JVMAInvZodDQ6mxuu5C',
#   31],
#  ['Mark Alow',
#   'Golden Tiger - Original',
#   'Golden Tiger',
#   2018,
#   'electronic',
#   '6uc9PEgKIuq21GPZ8pblai',
#   26],
#  ['Ryan Murgatroyd',
#   'Something Said - Ian Pooley Remix Edit',
#   'Something Said (Remixes)',
#   2018,
#   'electronic',
#   '5iCaSecV8cjACuVdmthBj0',
#   31],
#  ['Jon Hopkins',
#   'Emerald Rush - Edit',
#   'Singularity',
#   2018,
#   'electronic',
#   '7csAqjPSaxWNAXfd321ajh',
#   30],
#  ['Mick Gordon',
#   "Gettin' ready",
#   'Wolfenstein II: The New Colossus (Original Game Soundtrack)',
#   2018,
#   'electronic',
#   '1q3mkNYqBIzPnD1F9F4msm',
#   34],
#  ['Rey&Kjavik',
#   'Nahimana',
#   'Mountiri',
#   2018,
#   'electronic',
#   '5ah9Farh1JKw49ao8ibI4f',
#   33],
#  ['Moderat',
#   'Invaluable Waste from the Outlying Districts, Pt. 01',
#   'A Thought of Ecstasy',
#   2018,
#   'electronic',
#   '6Dq71ZqT8fBn6M5k9hgsG5',
#   25],
#  ['Justice',
#   'Alakazam ! x Fire (WWW)',
#   'Woman Worldwide',
#   2018,
#   'electronic',
#   '62XMD2zZ0SI9pDKOBuG9we',
#   34],
#  ['Aazar',
#   'Booty Time - Yellow Claw & Stoltenhoff Remix',
#   'Booty Time (Remix Pack)',
#   2018,
#   'electronic',
#   '2zkipwaDx4fuEAEnlZUbXT',
#   23],
#  ['Auntie Flo',
#   'Nobody Said It Would Be Easy',
#   'Radio Highlife',
#   2018,
#   'electronic',
#   '0nwTc3LVTsMeBhloELTaTm',
#   27],
#  ['Krystal Klear',
#   'Neutron Dance - Edit',
#   'Neutron Dance (Edit)',
#   2018,
#   'electronic',
#   '0h9xxCoXw2LkdJG9pR79RN',
#   31],
#  ['Thom Yorke',
#   'Open Again',
#   'Suspiria (Music for the Luca Guadagnino Film)',
#   2018,
#   'electronic',
#   '1NSudIh88CQ6ZSUCNEx6jV',
#   32],
#  ['Jon Hopkins',
#   'Luminous Beings',
#   'Singularity',
#   2018,
#   'electronic',
#   '3Ha9TeaqCdcS6cqKmFGCO3',
#   31],
#  ['Mnogoznaal',
#   'Z-PAM',
#   'Гостиница Космос',
#   2018,
#   'electronic',
#   '7a7LHuM2RnuqA8g0EyAwM8',
#   40],
#  ['Rhye',
#   'Blood Knows',
#   'Blood',
#   2018,
#   'electronic',
#   '5A3qVlLryOqCuAB1DXrn8t',
#   30],
#  ['Rhye',
#   'Song For You - Mansionair Remix',
#   'Blood Remixed',
#   2018,
#   'electronic',
#   '2tnFnMZvVIlaGrI50H2WSQ',
#   33],
#  ['Hooverphonic',
#   'Romantic',
#   'Looking For Stars',
#   2018,
#   'electronic',
#   '6UvHVnBPpxMJrTAFnMK8s2',
#   30],
#  ['Stavroz',
#   'Zorrow',
#   'Kasambila',
#   2018,
#   'electronic',
#   '0TDotBC76NVf2eR2vV2TZm',
#   30],
#  ['Fatboy Slim',
#   "Gangster Trippin' (Sultan & Shepard Remix)",
#   "Gangster Trippin' (Sultan & Shepard Remix)",
#   2018,
#   'electronic',
#   '7qcnHxORUCzKZsf711lJjd',
#   25],
#  ['Poshlaya Molly',
#   'Значит дружба',
#   'Грустная девчонка с глазами как у собаки',
#   2018,
#   'electronic',
#   '3dPTAlJJVqTenKzUkije3q',
#   44],
#  ['Paul Kalkbrenner',
#   'Part Seven',
#   'Parts of Life',
#   2018,
#   'electronic',
#   '3P64WezGLLzkWhfIu0rRSq',
#   27],
#  ['DROELOE',
#   'BACKBONE',
#   'BACKBONE',
#   2018,
#   'electronic',
#   '0TklENvWk96XWLk2qw2whN',
#   42],
#  ['Gab Rhome',
#   'Do Not Grill Inside',
#   'Rêveries Éphémères',
#   2018,
#   'electronic',
#   '3DvfpS02E1kH62f5oboLUZ',
#   26],
#  ['Novalima',
#   'La Despedida',
#   "Ch'usay",
#   2018,
#   'electronic',
#   '2JIgCGmlyoBRrHDi6Q8PSp',
#   22],
#  ['Gustavo Dominguez',
#   'Afro Voodoo - Original Mix',
#   'Afro Voodoo EP',
#   2018,
#   'electronic',
#   '69sHg75scB08oVdgf99WwN',
#   20],
#  ['islandman',
#   'Agit',
#   'Rest in Space',
#   2018,
#   'electronic',
#   '3mb2fkaJUlrRnwxGRGQAGS',
#   33],
#  ['Vigiland',
#   'Take This Ride',
#   'V',
#   2018,
#   'electronic',
#   '1bjd4UgjnK5hedJJKmi3YP',
#   35],
#  ['deadmau5',
#   'drama free',
#   'mau5ville: Level 2',
#   2018,
#   'electronic',
#   '7zHfKwqpf6OUfT02vQLhU5',
#   38],
#  ['Matanza',
#   'Samanke',
#   'Matanza',
#   2018,
#   'electronic',
#   '3IlBPR24FF6MXDxRii2WwX',
#   30],
#  ['Against All Logic',
#   'Some Kind of Game',
#   '2012 - 2017',
#   2018,
#   'electronic',
#   '3Bakse02jAOEMXkIMlPJsf',
#   33],
#  ['Amnesia Scanner',
#   'AS Too Wrong',
#   'Another Life',
#   2018,
#   'electronic',
#   '74wUpuW4tRQJJGiucm4JfJ',
#   26],
#  ['Monetochka',
#   'Нет монет',
#   'Раскраски для взрослых',
#   2018,
#   'electronic',
#   '74fJlgF0bEZAoKHpK1MdJs',
#   38],
#  ['Tube & Berger',
#   'Cabala King',
#   'Cabala King',
#   2018,
#   'electronic',
#   '7JQNOs10Kj2gmoQRwcR9JS',
#   26],
#  ['CA7RIEL',
#   'Nobokie',
#   'LIVRE',
#   2018,
#   'electronic',
#   '1Gr7lAVp0yOirRDyxFLR0o',
#   27],
#  ['ARTBAT',
#   'Prometheus',
#   'Planeta EP',
#   2018,
#   'electronic',
#   '6cKnTVBV1ALxJf6PHSpDWK',
#   29],
#  ['HamzeH',
#   'Dive (ASOT 877)',
#   'A State Of Trance Episode 877 [Hosted by MaRLo]',
#   2018,
#   'electronic',
#   '4WJM6ZDFhrssWzcfPsPpsQ',
#   29],
#  ['Carnage',
#   'Learn How to Watch (feat. Mac Miller & MadeinTYO)',
#   'Learn How to Watch (feat. Mac Miller & MadeinTYO)',
#   2018,
#   'electronic',
# ...
#   '1J8CqSsS6ErrveimQyCvZa',
#   26],
#  ['Miranda!',
#   'Iman',
#   'The History 2002-2007',
#   2018,
#   'electronic',
#   '5cwA7In3MlagrZvmcomdU5',
#   21],
#  ['Martin Jensen',
#   'Pull Up',
#   'Pull Up',
#   2018,
#   'electronic',
#   '3rBMaWZY1jXgVxmUwTi0Vk',
#   26],
#  ['Nicolas Godin',
#   'Quartier Général',
#   'Au service de la France',
#   2018,
#   'electronic',
#   '5GiQZvOqB4bgS2Zb27OrvB',
#   21],
#  ['Sahalé',
#   'Magharabì - Miss Babayaga DJ & DJ Josh Blackwell Remix',
#   'Magharabì',
#   2018,
#   'electronic',
#   '0YcuXZQ3wyVKdU3zgbmozA',
#   22],
#  ['RL Grime',
#   'Take It Away (Alexander Lewis Remix)',
#   'NOVA (The Remixes, Vol. 2)',
#   2018,
#   'electronic',
#   '6MBAqucA0D96MJYstNeHwD',
#   37],
#  ['Aphex Twin',
#   'MT1 t29r2',
#   'Collapse EP',
#   2018,
#   'electronic',
#   '7C7ugeGrEIN2gKfHLxickK',
#   25],
#  ['Forest Swords',
#   'Crow - DJ-Kicks',
#   'Crow (DJ-Kicks)',
#   2018,
#   'electronic',
#   '5kC8W931UhwuKFJ86UOsab',
#   21],
#  ['Elfenberg',
#   'Gaivota',
#   'Continents',
#   2018,
#   'electronic',
#   '218QscCA8iXsQNX2iunuHZ',
#   21],
#  ['ZULI',
#   'Trigger Finger',
#   'Trigger Finger',
#   2018,
#   'electronic',
#   '3hNvwpp9IQKuEBFyUuAIGN',
#   22],
#  ['Tycho', 'Jetty', 'Jetty', 2018, 'electronic', '4e0YtDwcwZuf8FCdjaMDWs', 32],
#  ['Ozoyo',
#   'Chiosfruits',
#   'Lost Beats',
#   2018,
#   'electronic',
#   '5OQdIcgjpzw4XsmGnDaxU0',
#   23],
#  ['Marco Tegui',
#   'Manan Kanchu',
#   'Kindisch Steps XII',
#   2018,
#   'electronic',
#   '4G3LAVjWO91Ew92NN51R6o',
#   22],
#  ['Underworld',
#   'I’ll See Big',
#   'Teatime Dub Encounters',
#   2018,
#   'electronic',
#   '0I4J6viflABqqIKvcKedxs',
#   20],
#  ['The Crystal Method',
#   'Ghost In The City',
#   'The Trip Home',
#   2018,
#   'electronic',
#   '1aY3V6zFCgnWABjVS18Z1i',
#   26],
#  ['Against All Logic',
#   'You Are Going to Love Me and Scream',
#   '2012 - 2017',
#   2018,
#   'electronic',
#   '5vgpBRqzkRu2XSsoSDlv9Q',
#   26],
#  ['Orbital',
#   'P.H.U.K.U.',
#   'P.H.U.K.U.',
#   2018,
#   'electronic',
#   '1BCl7QXWC9nwpm4vKCktXJ',
#   22],
#  ['GusGus',
#   "Don't Know How to Love",
#   'Lies Are More Flexible',
#   2018,
#   'electronic',
#   '5YWKqzLqLcfZgu3nBShURg',
#   18],
#  ['Karma Fields',
#   'CODE 10-31',
#   'CODE 10-31',
#   2018,
#   'electronic',
#   '1YljaQqSKeUzYX2WLiN38r',
#   29],
#  ['Death In Vegas',
#   'Honey',
#   'Honey',
#   2018,
#   'electronic',
#   '63tjBysMkYOHJMEjEL0ODD',
#   23],
#  ['Pensees',
#   'Planetary - Original Mix',
#   'Movement',
#   2018,
#   'electronic',
#   '2BmOKRrrRv6JmsypuCc401',
#   28],
#  ['LOUTA',
#   'ENCHASTRE',
#   'ENCHASTRE',
#   2018,
#   'electronic',
#   '2s2clG1RlW4YbJisaQT9aL',
#   24],
#  ['WATEVA',
#   'Amnesia',
#   'Amnesia',
#   2018,
#   'electronic',
#   '3lyZ3wS81yeUx8V8ORjeeB',
#   26],
#  ['Lucky Luke',
#   'Out of Touch',
#   'Out of Touch',
#   2018,
#   'electronic',
#   '32BTg5fwJtYnfFBrUFN19S',
#   29],
#  ['Armen Miran',
#   'Jojo In The Stars - Ali Farahani Remix',
#   'Lost Found EP (The Remixes)',
#   2018,
#   'electronic',
#   '3owTyzl8OH5oopzZxhSvgI',
#   22],
#  ['Quatri (FR)',
#   'Jana',
#   'Jana',
#   2018,
#   'electronic',
#   '1PR1aispUJaUHnld5tnqvy',
#   22],
#  ['Babasonicos',
#   'Partícula',
#   'Discutible',
#   2018,
#   'electronic',
#   '0DiIIEstbNXB8aw8oUAdfr',
#   27],
#  ['Francisca Valenzuela',
#   'Ya No Se Trata de Ti',
#   'Ya No Se Trata de Ti',
#   2018,
#   'electronic',
#   '1AJBNdi266U3cJkgxpHOlF',
#   35],
#  ['LOUTA',
#   'TODOS CON EL CELU',
#   'ENCHASTRE',
#   2018,
#   'electronic',
#   '0zwqCbNKpeDxytxPxi2sz6',
#   23],
#  ['Hooverphonic',
#   'Paranoid Affair',
#   'Looking For Stars',
#   2018,
#   'electronic',
#   '4lPHdMXICqdl6RguxO2jBK',
#   20],
#  ['Miranda!',
#   'Enamorada',
#   'The History 2002-2007',
#   2018,
#   'electronic',
#   '0jCPf46x13oPbKForEV0nd',
#   22],
#  ['Danito & Athina',
#   'Kyra',
#   'Kyra',
#   2018,
#   'electronic',
#   '6e0o8b8I6IVKcOgTYq3wkU',
#   22],
#  ['EURINGER',
#   'Do You Kiss Your Mama with That Mouth?',
#   'EURINGER',
#   2018,
#   'electronic',
#   '634VMOSVmxhKDbNdvI8ghu',
#   31],
#  ['Jimi Tenor',
#   'Mysteria',
#   'Order of Nothingness',
#   2018,
#   'electronic',
#   '0KuQb8txBBN5NxlHGzUYyu',
#   18],
#  ['Solomun',
#   'Dre',
#   'Customer Is King EP',
#   2018,
#   'electronic',
#   '0E69kyrQHaG3q6q8UtaiO1',
#   21],
#  ['Dapa Deep',
#   'This Boy',
#   'Seasons',
#   2018,
#   'electronic',
#   '7u2Gljs2VOa5XSQosAIC2p',
#   22],
#  ['Dean Blunt',
#   'CRUSHED',
#   'Soul On Fire',
#   2018,
#   'electronic',
#   '7s7upFAUfe8FMs2VOG95Fl',
#   27],
#  ['CREAM SODA',
#   'Уйди, но останься',
#   'Красиво',
#   2018,
#   'electronic',
#   '1eC3rkuJHlitGAhtIwul8p',
#   27],
#  ['Thom Yorke',
#   'The Universe is Indifferent',
#   'Suspiria (Music for the Luca Guadagnino Film)',
#   2018,
#   'electronic',
#   '4F3fsYWLVocXFzbpmHQY2Z',
#   20],
#  ['CLUBZ',
#   'El Rollo',
#   'Destellos',
#   2018,
#   'electronic',
#   '5sURcqvepZmEMLmakSjJAG',
#   30],
#  ['Stavroz',
#   'Kasambila',
#   'Kasambila',
#   2018,
#   'electronic',
#   '2dbGtJxDKUsEehUzMbNkZm',
#   22],
#  ['Totally Enormous Extinct Dinosaurs',
#   "Don't You Forget About Me",
#   "Don't You Forget About Me",
#   2018,
#   'electronic',
#   '7IidnemjastTResAXISAK7',
#   28],
#  ['Charlotte Adigéry',
#   'Paténipat - Edit',
#   'Paténipat (Edit)',
#   2018,
#   'electronic',
#   '55xxgCKNoQv4AeZLtrRWWy',
#   16],
#  ['Lookas',
#   'Deep Breaths',
#   'Deep Breaths',
#   2018,
#   'electronic',
#   '2rqR1bvEAmLHCNWBvyDt0V',
#   29],
#  ['Geju',
#   'Kairosmind',
#   'Water Elements',
#   2018,
#   'electronic',
#   '0wmsIEMUdPD7NUfS5LzsJ3',
#   22],
#  ['Boombox Cartel',
#   'People I Know',
#   'People I Know',
#   2018,
#   'electronic',
#   '2pvS2qIkOSFlvLkGBAgQ2o',
#   38],
#  ['Ten Walls',
#   'Hidden',
#   'Hidden',
#   2018,
#   'electronic',
#   '0mkHIJkxpYeAhLFug0IgCC',
#   22],
#  ['Mick Gordon',
#   'Der Zitadelle',
#   'Wolfenstein II: The New Colossus (Original Game Soundtrack)',
#   2018,
#   'electronic',
#   '6BwfKDvACMdnYoFTS8O4nQ',
#   26],
#  ['Alison Wonderland',
#   'High',
#   'Awake',
#   2018,
#   'electronic',
#   '5qdPqyF6mc5rJBmQW5ppgA',
#   36],
#  ['Shinichi Atobe',
#   'Heat 1',
#   'Heat',
#   2018,
#   'electronic',
#   '7KtbZxJU9ZdIyJJ4QMzx66',
#   25],
#  ['Miranda!',
#   'Cena para Cuatro - Remastered 2018',
#   'Greatest Feats',
#   2018,
#   'electronic',
#   '1iP5iazxRCrs9YXU2sjR1Q',
#   20],
#  ['Be Svendsen',
#   'Flint',
#   'Between a Smile and a Tear',
#   2018,
#   'electronic',
#   '1cj3rNifHmHL6KWUQmqIC6',
#   22],
#  ['KILNAMANA',
#   'Kill the Kool',
#   'Kill the Kool',
#   2018,
#   'electronic',
#   '5qkRF0huMmD9poqRHV6wmE',
#   24],
#  ['KVPV',
#   'Problems',
#   'Problems',
#   2018,
#   'electronic',
#   '1HPoVrgKfEMDPO1kyWutxB',
#   29],
#  ['Against All Logic',
#   'Hopeless',
#   '2012 - 2017',
#   2018,
#   'electronic',
#   '0qAwGOJawUM6ASQLlbUSQp',
#   26],
#  ['Vladimir Dubyshkin',
#   'Belissimo',
#   'Cheerful Pessimist',
#   2018,
#   'electronic',
#   '6AIPf2y0Te8AakuhaVlXQG',
#   22],
#  ['Róisín Murphy',
#   'Plaything',
#   'Plaything / Like',
#   2018,
#   'electronic',
#   '3CRuaG93yRRpSkPjTwsjF9',
#   20],
#  ['MORTEN',
#   'Family (feat. Dave East)',
#   'Family (feat. Dave East)',
#   2018,
#   'electronic',
#   '401APsQhssrPs5Pm90048p',
#   25],
#  ['CRASPORE',
#   'Затмение',
#   'Затмение',
#   2018,
#   'electronic',
#   '2JnMGPlIun9hmXjmsc1m9n',
#   30],
#  ['Jose Solano',
#   'Los Jardines Colgantes',
#   'Alba',
#   2018,
#   'electronic',
#   '0z6rZDrsyTBejWPaqZVD5A',
#   22],
#  ['AL-90',
#   '000903',
#   'Murmansk-60',
#   2018,
#   'electronic',
#   '7M3VDzJ9kYHW4zI2eO1z1i',
#   29],
#  ['Pejzaż',
#   'Bałtyk',
#   'Ostatni Dzień Lata',
#   2018,
#   'electronic',
#   '6xzlsvpK26wuY949R21CgM',
#   25],
#  ['MD DJ',
#   'Want it More - Original Mix',
#   'Deep House Ibiza',
#   2018,
#   'electronic',
#   '0gV6RWyUcnPxwpHgEu7DOB',
#   19],
#  ['Soulwax',
#   'Essential Three',
#   'ESSENTIAL',
#   2018,
#   'electronic',
#   '2ldXSi2Ztad1MBxCVkS3GE',
#   20],
#  ['Lovebirds',
#   'Dove Sei - Original Deep Mix',
#   'Dove Sei',
#   2018,
#   'electronic',
#   '06HIzgf7QaglqWUD1clCJ6',
#   21],
#  ['Jay Ocean',
#   'Adventure',
#   'Adventure',
#   2018,
#   'electronic',
#   '4s40xWqqO8U83hZ8rCnLmx',
#   29],
#  ['Peces Raros',
#   'Sol Negro',
#   'Anestesia',
#   2018,
#   'electronic',
#   '4aWzORLGqeiUf7HTHimlFA',
#   25],
#  ["Argatu'",
#   'Sa Rasune-N Tara Noastra',
#   'Vol. 2',
#   2018,
#   'electronic',
#   '7rCJjgNG7fAOroqKZ4wLvG',
#   21],
#  ['David Hohme',
#   'Fear Less - Hraach Remix - Mixed',
#   'Where My Heart Is, Vol. 1',
#   2018,
#   'electronic',
#   '1gC67cR9GIUhY5Bvl9czRY',
#   20],
#  ['Moby',
#   'Like a Motherless Child',
#   'Everything Was Beautiful, and Nothing Hurt',
#   2018,
#   'electronic',
#   '1hVcWHJTjuRpwAma92a2ti',
#   18],
#  ['Giant Swan',
#   'Pax Britannica',
#   'Whities 016',
#   2018,
#   'electronic',
#   '0yJgStMHZSZRw0i1kyF2Ul',
#   21],
#  ['Grouch in Dub',
#   'Back to Reality',
#   'Grouch in Dub',
#   2018,
#   'electronic',
#   '2yA1htGjuEDQsoLy03sDPZ',
#   24],
#  ['Traf',
#   'Freed From Memories (Cathedral Edit)',
#   'Freed From Memories',
#   2018,
#   'electronic',
#   '29xXZaufmPpuDEdI2lZWJU',
#   23],
#  ["Argatu'",
#   'Cine Iubeste Si Lasa',
#   'Vol. 4',
#   2018,
#   'electronic',
#   '66hDznGmCAIDVCWEzUVtiu',
#   24],
#  ['Alison Wonderland',
#   'Cry',
#   'Awake',
#   2018,
#   'electronic',
#   '0CqGCpNdOktUrsTUEkWozV',
#   36],
#  ['Javiera Mena',
#   'Espejo',
#   'Espejo',
#   2018,
#   'electronic',
#   '0SibPl0V9rpSmaqx4mXzmV',
#   18],
#  ['Dean Blunt',
#   'NBA',
#   'Soul On Fire',
#   2018,
#   'electronic',
#   '2dZZvLO6OdDwi4rK9vak3r',
#   30],
#  ['JayKode',
#   'Careful',
#   'Careful',
#   2018,
#   'electronic',
#   '79kJrZE0piEeYNBfsTskYm',
#   29],
#  ['Django Django',
#   'Swimming at Night',
#   "Winter's Beach",
#   2018,
#   'electronic',
#   '2KjeYJJZok4Ed7AYn8UGau',
#   18],
#  ['Keys N Krates',
#   'Something Wonderful',
#   'Cura',
#   2018,
#   'electronic',
#   '4zNbp8mu1b56hqKdas7POk',
#   32],
#  ['Miranda!',
#   'Traición',
#   'The History 2002-2007',
#   2018,
#   'electronic',
#   '5yMCAQvSYHwIWMr6U2xgSP',
#   25],
#  ['Novalima',
#   'Alcajazz',
#   'Afro',
#   2018,
#   'electronic',
#   '074WIYfdK8F7hr6CKPFreA',
#   15],
#  ['Herobust',
#   'WTF - MARAUDA Remix',
#   'WTF VIP + Remixes',
#   2018,
#   'electronic',
#   '113Bna2K6ed4rs3wIcQSPw',
#   33],
#  ['Grouch in Dub',
#   'Dublisious',
#   'Grouch in Dub',
#   2018,
#   'electronic',
#   '6LiENuDIFjv8RSXIUEFo18',
#   26],
#  ['CA7RIEL',
#   'Oh Shit',
#   'POVRE',
#   2018,
#   'electronic',
#   '2wCRcHVTv4MvRGIok61MUG',
#   18],
#  ['Novalima',
#   'Malivio Son',
#   'Karimba',
#   2018,
#   'electronic',
#   '6wxHU4Tjd1SeXZkTPz9tAk',
#   13],
#  ['Boombox Cartel',
#   'Whisper',
#   'Whisper',
#   2018,
#   'electronic',
#   '7uqXoZoKZKjuRdNphOQOgU',
#   36],
#  ['Mad Zach',
#   'Noth',
#   'Noth',
#   2018,
#   'electronic',
#   '035epJwRLJQLXbQ7XtPFEf',
#   31],
#  ['Portico Quartet',
#   'Index',
#   'Untitled (AITAOA #2)',
#   2018,
#   'electronic',
#   '09dewzTCTmDZ8x0QU3siUT',
#   21],
#  ['RL Grime', 'Era', 'NOVA', 2018, 'electronic', '4JSYn5C2Tgf8foScoMKBwM', 30],
#  ['Habstrakt',
#   'Vibin',
#   'Vibin',
#   2018,
#   'electronic',
#   '0tnFKjEEsjD3AVShRgtIun',
#   30],
#  ['3R2',
#   'Pancake Is Love',
#   'Pancake Is Love',
#   2018,
#   'electronic',
#   '3xSc6ofg2Q2v825OmoBRsM',
#   27],
#  ['EURINGER',
#   'Random EMO Top Line Generator',
#   'EURINGER',
#   2018,
#   'electronic',
#   '19AE321Ry73c7Rmt3c7SsT',
#   29],
#  ['The Crystal Method',
#   'Hold on to Something',
#   'The Trip Home',
#   2018,
#   'electronic',
#   '3sTeTGryCQJNqqEkx3uJ6A',
#   25],
#  ['LOUTA',
#   'UACHO (feat. Marilina Bertoldi)',
#   'ENCHASTRE',
#   2018,
#   'electronic',
#   '6FJEE7fL0XZb80TYq7nygf',
#   26],
#  ['Guy Gerber',
#   'What To Do',
#   'What to Do EP',
#   2018,
#   'electronic',
#   '4vzaziL73RNSeEUD7TjfWJ',
#   19],
#  ['Miranda!',
#   'El Profe',
#   'The History 2002-2007',
#   2018,
#   'electronic',
#   '5BZL2oQz7wERlR6UeVhDa5',
#   22],
#  ['Kermesse',
#   'Bleepio',
#   'Kermesse',
#   2018,
#   'electronic',
#   '2UDrB2AEK3VrqpDnemg3MV',
#   18],
#  ['MD DJ',
#   'My Love - Original Mix',
#   'Deep House Ibiza',
#   2018,
#   'electronic',
#   '0oxORnENetMzTDLDS5NUU0',
#   19],
#  ['Manuel Darquart',
#   'Drunk Sundays',
#   'Dippin & Trippin',
#   2018,
#   'electronic',
#   '7HARmWLSb1quqaEGNuIudB',
#   23],
#  ['Klunsh',
#   'Haryu Marka',
#   'Sónar 25: An advanced music mixtape by Black Coffee',
#   2018,
#   'electronic',
#   '3TWQDRvxyBCktOT6zuYDty',
#   20],
#  ['GusGus',
#   'Lies Are More Flexible',
#   'Lies Are More Flexible',
#   2018,
#   'electronic',
#   '0c70dwBiKt4sqQ3kUUilxn',
#   18],
#  ['San Holo',
#   'surface',
#   'album1',
#   2018,
#   'electronic',
#   '0Gg7eD8YjntgZVFZO5LY8R',
#   29],
#  ['Taz & Meeks',
#   'Obviously - Mixed',
#   'DJ-Kicks (Mount Kimbie) [DJ Mix]',
#   2018,
#   'electronic',
#   '3pyVQshWaFVwvc5KZYFthL',
#   24],
#  ['Good Times Ahead',
#   'I Can’t Hold On',
#   'Death To Genres (Vol. 3)',
#   2018,
#   'electronic',
#   '2e6he0ydsChPv44oTVC7CO',
#   29],
#  ['GusGus',
#   'Lifetime',
#   'Lies Are More Flexible',
#   2018,
#   'electronic',
#   '4J6tV8auDoaCS1iAnD0IRK',
#   15],
#  ['Kasper Marott',
#   'Keflavik',
#   'Keflavik EP',
#   2018,
#   'electronic',
#   '5SSt1W5fEZgMfU5J2odjiT',
#   21],
#  ['Tunacola',
#   'El Viento Que Nos Lleva a los Dos',
#   'En el Centro de la Fiesta Está el Vacío, Pero en el Centro del Vacío Hay Otra Fiesta',
#   2018,
#   'electronic',
#   '2NeOGCaTPh9gL5XhVg7vfk',
#   25],
#  ['Francisco Victoria',
#   'Marinos',
#   'Prenda',
#   2018,
#   'electronic',
#   '4hqv3GkkUgglx2LIpk0DfS',
#   29],
#  ['Ross from Friends',
#   'Project Cybersyn',
#   'Family Portrait',
#   2018,
#   'electronic',
#   '39L1ci8l2THU5Nh1dbBIrM',
#   25],
#  ['Lovebirds',
#   'Dove Sei - Original Vinyl Only Version',
#   'Dove Sei',
#   2018,
#   'electronic',
#   '6op44JmbJAm4NvixaHrJhE',
#   19],
#  ['Morcheeba',
#   'Love Dub',
#   'Blaze Away',
#   2018,
#   'electronic',
#   '3l1DZh65UoxC7GHJ9xQs1n',
#   16],
#  ['Black Math',
#   'Point Blank (Alternate)',
#   'Point Blank',
#   2018,
#   'electronic',
#   '5uHDXkspXujscb2rpojWmL',
#   25],
#  ['Dirty Doering',
#   'Burning Ham',
#   'Euch die Uhren uns die Zeit',
#   2018,
#   'electronic',
#   '4isvEXQmqDXzpOin4Oh4wu',
#   21],
#  ['Jon Sable',
#   'Housework',
#   'Alishan Forest Railway / Housework',
#   2018,
#   'electronic',
#   '5ovtRPwMmmE5iKTkgI60Bw',
#   23],
#  ['Nu',
#   'Who Loves The Sun - Edit',
#   'Bar 25: Greatest Hits',
#   2018,
#   'electronic',
#   '4k46rRWlWaimo8oy8nCHcZ',
#   19],
#  ['Alt8',
#   'Amsterdam (Gdwa8)',
#   'Amsterdam (Gdwa8)',
#   2018,
#   'electronic',
#   '1qpIazDGUBGFuPunGd28pT',
#   20],
#  ['Krovostok',
#   'Злые голуби',
#   'ЧБ (Deluxe Version)',
#   2018,
#   'electronic',
#   '4rXJaP5cUO0TinLnnq4W0W',
#   29],
#  ['Die Wilde Jagd',
#   '2000 Elefanten',
#   'Uhrwald Orange',
#   2018,
#   'electronic',
#   '2ufkztgsyPMB198a2jCP7F',
#   27],
#  ['The Crystal Method',
#   "Let's Go Home",
#   'The Trip Home',
#   2018,
#   'electronic',
#   '3QKRieCKFvO0pHjtGK7B7k',
#   22],
#  ['BICEP',
#   'Helix',
#   'Rain EP',
#   2018,
#   'electronic',
#   '3i6qmDVRuV8dzENGl2MuAg',
#   23],
#  ['Leon Vynehall',
#   'Trouble - Parts I, II, & III (Chapter V)',
#   'Nothing Is Still',
#   2018,
#   'electronic',
#   '38LwS4tE7hOdstQtCA1fom',
#   24],
#  ['Nu',
#   'Pensamiento',
#   'Pensamiento',
#   2018,
#   'electronic',
#   '3pK9iOYYa8FOQSfm74Ys7K',
#   17],
#  ['Keys N Krates',
#   'Glitter (feat. Ambré Perkins)',
#   'Cura',
#   2018,
#   'electronic',
#   '5C5rOcWgXTwRfcYVqQ2bPQ',
#   29],
#  ['Mnogoznaal',
#   'JUD',
#   'Гостиница Космос',
#   2018,
#   'electronic',
#   '1g1r3IGfdiuuopVQlim55R',
#   27],
#  ['Miranda!',
#   'Hola',
#   'The History 2002-2007',
#   2018,
#   'electronic',
#   '50vjj5Yl95OFhJMamTooDE',
#   21],
#  ['RL Grime',
#   'Atoms (Said the Sky Remix)',
#   'NOVA (The Remixes, Vol. 1)',
#   2018,
#   'electronic',
#   '5in8wHKDJ3tc0TdLucnPqv',
#   39],
#  ['Vigiland',
#   'Nice To Meet You',
#   'V',
#   2018,
#   'electronic',
#   '7GfVVc0J7EEUnKyhrqvlzT',
#   28],
#  ['Stavroz',
#   'Perron 11',
#   'Kasambila',
#   2018,
#   'electronic',
#   '7nJYwLx0VjTqF5eCirrUoU',
#   20],
#  ['What So Not',
#   'Beautiful',
#   'Not All the Beautiful Things',
#   2018,
#   'electronic',
#   '0o7NRqrv7cOZ2T3OoIVUiD',
#   19],
#  ['Jeremy Vancaulart',
#   'Hurt (ASOT 850 - Part 2) [Future Favorite]',
#   'A State Of Trance Episode 850 (Part 2) [+ XXL Guest Mix: Gareth Emery & Ashley Wallbridge]',
#   2018,
#   'electronic',
#   '1VRmuih567Fvly4UOaKZYT',
#   21],
#  ['Morat',
#   'Cuando Nadie Ve',
#   'Balas Perdidas',
#   2018,
#   'pop',
#   '71iAechwVKGu26pahzFL0k',
#   76],
#  ['Sia',
#   'Snowman',
#   'Everyday Is Christmas (Deluxe Edition)',
#   2018,
#   'pop',
#   '7uoFMmxln0GPXQ0AcCBXRq',
#   90],
#  ['Morat',
#   'Besos En Guerra',
#   'Balas Perdidas',
#   2018,
#   'pop',
#   '1mlGScrDQqHqmhdIqE8MmA',
#   75],
#  ['Morat',
#   'No Se Va',
#   'Balas Perdidas',
#   2018,
#   'pop',
#   '4khWEpnaijN0G1x019Uzdr',
#   77],
#  ['Manuel Carrasco',
#   'Qué Bonito Es Querer',
#   'La Cruz Del Mapa',
#   2018,
#   'pop',
#   '6uzGmmQ4CuG9HvZktEy0LF',
#   61],
#  ['Melendi',
#   'Destino o casualidad',
#   'Destino o casualidad',
#   2018,
#   'pop',
#   '2sMxswHr9wX7kTUHULvJBJ',
#   71],
#  ['Lady Gaga',
#   'Shallow',
#   'A Star Is Born Soundtrack',
#   2018,
#   'pop',
#   '2VxeLyX666F8uXCJ0dZF8B',
#   81],
#  ...]

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab', host='127.0.0.1', database='proyecto_spoti')

# %%
cursor = cnx.cursor()

# %%
query = """
INSERT INTO pistas_spoti (artista, cancion, album, año, genero, spotify_id, popularidad)
VALUES (%s, %s, %s, %s, %s, %s, %s);
"""

cursor.executemany(query, resultados_pistas)

cnx.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\Usuario\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:706, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     705         query = query.encode("utf-8")
# --> 706     self._cmysql.query(
#     707         query,
#     708         raw=raw,
#     709         buffered=buffered,
#     710         raw_as_string=raw_as_string,
#     711         query_attrs=self.query_attrs,
#     712     )
#     713 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Lock wait timeout exceeded; try restarting transaction
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[41], line 6
#       1 query = """
#       2 INSERT INTO pistas_spoti (artista, cancion, album, año, genero, spotify_id, popularidad)
#       3 VALUES (%s, %s, %s, %s, %s, %s, %s);
#       4 """
# ----> 6 cursor.executemany(query, resultados_pistas)
#       8 cnx.commit()
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\mysql\connector\cursor_cext.py:481, in CMySQLCursor.executemany(self, operation, seq_params)
#     479     if stmt is not None:
#     480         self._executed = stmt
# --> 481         return self.execute(stmt)
#     483 rowcnt = 0
#     484 try:
#     485     # When processing read ops (e.g., SELECT), rowcnt is updated
#     486     # based on self._rowcount. For write ops (e.g., INSERT) is
#     487     # updated based on self._affected_rows.
#     488     # The variable self._description is None for write ops, that's
#     489     # why we use it as indicator for updating rowcnt.
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\mysql\connector\cursor_cext.py:357, in CMySQLCursor.execute(self, operation, params, multi)
#     352             raise ProgrammingError(
#     353                 "Not all parameters were used in the SQL statement"
#     354             )
#     356 try:
# --> 357     result = self._connection.cmd_query(
#     358         stmt,
#     359         raw=self._raw,
#     360         buffered=self._buffered,
#     361         raw_as_string=self._raw_as_string,
#     362     )
#     363 except MySQLInterfaceError as err:
#     364     raise get_mysql_exception(
#     365         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     366     ) from err
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:714, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     706     self._cmysql.query(
#     707         query,
#     708         raw=raw,
#    (...)
#     711         query_attrs=self.query_attrs,
#     712     )
#     713 except MySQLInterfaceError as err:
# --> 714     raise get_mysql_exception(
#     715         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     716     ) from err
#     717 except AttributeError as err:
#     718     addr = (
#     719         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     720     )
#
# DatabaseError: 1205 (HY000): Lock wait timeout exceeded; try restarting transaction
