# %%
import requests
import pandas as pd
import mysql.connector
# !pip install pandas mysql-connector-python

# %%
df = pd.read_csv('./CSV/resultados_artistas3.csv')

# %%
df = df.drop_duplicates(subset=["Artista"], keep='first')

# %%
df.fillna('Sin datos', inplace=True)

# %%
resultados_artistas = df.values.tolist()

# %%
resultados_artistas
# Out:
# [['Elephant Tree',
#   766694,
#   55083,
#   'Elephant Tree are a new band, just about to start cutting their teeth in the London metal scene. Having moved down and taken in many many gigs and shows the guys have been influenced to start making their own music. Linking up with Pete of Trippy Wicked & the Cosmic Children of the Knight and Stubb in early January and Riley \'Sitar Wizard\' MacIntyre soon after, things are snowballing quickly with more songs in the pipelines.  Recording in the summer for their first EP <a href="https://www.last.fm/music/Elephant+Tree">Read more on Last.fm</a>',
#   'Lowrider, Spaceslug, King Buffalo, Mars Red Sky, 1000mods'],
#  ["Mother's Cake",
#   651823,
#   51037,
# ...

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab', host='127.0.0.1', database='proyecto_spoti')

# %%
cursor = cnx.cursor()

# %%
query = """
INSERT INTO resultados_artistas_lastfm (Artista, Reproducciones, Oyentes, Biografía, Artistas_Similares)
VALUES (%s, %s, %s, %s, %s);
"""

cursor.executemany(query, resultados_artistas)

cnx.commit()

# %%
#POSIBLE SOLUCIÓN DE CHATTY

query_check_artist = "SELECT nombre FROM resultados_artistas_lastfm"
cursor.execute(query_check_artist)

# Fetch all valid artist names
valid_artists = set(row[0] for row in cursor.fetchall())

# Filter the input data to include only rows with valid foreign keys
filtered_pistas = [
    pista for pista in resultados_pistas1 if pista[0] in valid_artists
]

# Insert the filtered data into pistas_spoti
query_insert = """
INSERT INTO pistas_spoti (artista, cancion, album, año, genero, spotify_id, popularidad)
VALUES (%s, %s, %s, %s, %s, %s, %s);
"""

if filtered_pistas:
    cursor.executemany(query_insert, filtered_pistas)
    cnx.commit()
    print(f"Inserted {len(filtered_pistas)} rows into pistas_spoti.")
else:
    print("No valid rows to insert.")

# %%
#2
df_pistas1 = pd.read_csv('./CSV/pistas1_5000.csv')

# %%
df_pistas1.fillna('Sin datos', inplace=True)

# %%
resultados_pistas1 = df_pistas1.values.tolist()

# %%
resultados_pistas1
# Out:
# [['DJ Snake',
#   'Taki Taki (with Selena Gomez, Ozuna & Cardi B)',
#   'Taki Taki (with Selena Gomez, Ozuna & Cardi B)',
#   2018,
#   'electronic',
#   '4w8niZpiMy6qz1mntFA5uM',
#   70],
#  ['Maribou State',
#   'Vale',
#   'Kingdoms In Colour',
#   2018,
#   'electronic',
#   '58FsmlVRQxpjFmXF8vSKMT',
#   64],
#  ['Xinobi',
#   'Far Away Place - Rampa Remix',
#   'Far Away Place (Rampa Remix)',
#   2018,
#   'electronic',
#   '4SpESjSScmJyuMamD9MKOL',
#   61],
#  ['Rhye',
#   'Song For You',
#   'Blood',
#   2018,
#   'electronic',
#   '0BfLvshnvJldGROufmYCrv',
#   53],
#  ['Rhye',
#   'Feel Your Weight - Poolside Remix',
#   'Blood Remixed',
#   2018,
#   'electronic',
#   '1hgX0ZmmP7IRRjUFCIBrnQ',
#   60],
#  ['Ash',
#   'Sing It Back (feat. Naila)',
#   'Sing It Back (feat. Naila)',
#   2018,
#   'electronic',
#   '2UhRf78iodPFuJa7TGMSFn',
#   65],
#  ['Maribou State',
#   'Nervous Tics',
#   'Kingdoms In Colour',
#   2018,
#   'electronic',
#   '2oJ8Il24SIiDCJv39RYzPp',
# ...

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab', host='127.0.0.1', database='proyecto_spoti')

# %%
cursor = cnx.cursor()

# %%
query = """
INSERT INTO pistas_spoti (artista, cancion, album, año, genero, spotify_id, popularidad)
VALUES (%s, %s, %s, %s, %s, %s, %s);
"""

cursor.executemany(query, resultados_pistas1)

cnx.commit()

# %%
df_pistas2 = pd.read_csv('./CSV/pistas5001_10000.csv')
df_pistas2.fillna('Sin datos', inplace=True)
resultados_pistas2 = df_pistas2.values.tolist()
resultados_pistas2
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab', host='127.0.0.1', database='proyecto_spoti') 
cursor = cnx.cursor()
query = """
INSERT INTO pistas_spoti (artista, cancion, album, año, genero, spotify_id, popularidad)
VALUES (%s, %s, %s, %s, %s, %s, %s);
"""

cursor.executemany(query, resultados_pistas2)

cnx.commit()

# %%
df_pistas3 = pd.read_csv('./CSV/pistas10001_15000.csv')
df_pistas3.fillna('Sin datos', inplace=True)
resultados_pistas3 = df_pistas3.values.tolist()
resultados_pistas3
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab', host='127.0.0.1', database='proyecto_spoti') 
cursor = cnx.cursor()
query = """
INSERT INTO pistas_spoti (artista, cancion, album, año, genero, spotify_id, popularidad)
VALUES (%s, %s, %s, %s, %s, %s, %s);
"""

cursor.executemany(query, resultados_pistas3)

cnx.commit()

# %%
df_pistas4 = pd.read_csv('./CSV/pistas15001_20000.csv')
df_pistas4.fillna('Sin datos', inplace=True)
resultados_pistas4 = df_pistas4.values.tolist()
resultados_pistas4
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab', host='127.0.0.1', database='proyecto_spoti') 
cursor = cnx.cursor()
query = """
INSERT INTO pistas_spoti (artista, cancion, album, año, genero, spotify_id, popularidad)
VALUES (%s, %s, %s, %s, %s, %s, %s);
"""

cursor.executemany(query, resultados_pistas4)

cnx.commit()
